# %%
import pandas
import numpy

# %%
data = pandas.read_csv(r'OneDrive\Desktop\cars.csv')

# %%
data
# Out:
#       Make                    Model   Type  Origin DriveTrain   MSRP  Invoice  \
# 0    Acura                      MDX    SUV    Asia        AWD  36945    33337
# 1    Acura           RSX Type S 2dr  Sedan    Asia        FWD  23820    21761
# 2    Acura                  TSX 4dr  Sedan    Asia        FWD  26990    24647
# 3    Acura                   TL 4dr  Sedan    Asia        FWD  33195    30299
# 4    Acura               3.5 RL 4dr  Sedan    Asia        FWD  43755    39014
# ..     ...                      ...    ...     ...        ...    ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe        FWD  40565    38203
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe        FWD  42565    40083
# 425  Volvo               S80 T6 4dr  Sedan  Europe        FWD  45210    42573
# 426  Volvo                      V40  Wagon  Europe        FWD  26135    24641
# 427  Volvo                     XC70  Wagon  Europe        AWD  35145    33112
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0           3.5        6.0         265        17           23    4451
# 1           2.0        4.0         200        24           31    2778
# 2           2.4        4.0         200        22           29    3230
# 3           3.2        6.0         270        20           28    3575
# 4           3.5        6.0         225        18           24    3880
# ..          ...        ...         ...       ...          ...     ...
# 423         2.4        5.0         197        21           28    3450
# 424         2.3        5.0         242        20           26    3450
# 425         2.9        6.0         268        19           26    3653
# 426         1.9        4.0         170        22           29    2822
# 427         2.5        5.0         208        20           27    3823
#
#      Wheelbase  Length
# 0          106     189
# 1          101     172
# 2          105     183
# 3          108     186
# 4          115     197
# ..         ...     ...
# 423        105     186
# 424        105     186
# 425        110     190
# 426        101     180
# 427        109     186
#
# [428 rows x 15 columns]

# %% [markdown]
# ## Question 1

# %% [markdown]
# **Cramer's V**

# %%
col = ['Make', 'Origin', 'Type']
df = data[col]
df
# Out:
#       Make  Origin   Type
# 0    Acura    Asia    SUV
# 1    Acura    Asia  Sedan
# 2    Acura    Asia  Sedan
# 3    Acura    Asia  Sedan
# 4    Acura    Asia  Sedan
# ..     ...     ...    ...
# 423  Volvo  Europe  Sedan
# 424  Volvo  Europe  Sedan
# 425  Volvo  Europe  Sedan
# 426  Volvo  Europe  Wagon
# 427  Volvo  Europe  Wagon
#
# [428 rows x 3 columns]

# %%
from itertools import combinations, product, chain

# %%
a = combinations(col, 2)
lst = [a for a in a]
lst
# Out:
# [('Make', 'Origin'), ('Make', 'Type'), ('Origin', 'Type')]

# %%
def cramer_V(obsCount):
    xNCat = obsCount.shape[0]
    yNCat = obsCount.shape[1]
    cTotal = obsCount.sum(axis = 1)
    rTotal = obsCount.sum(axis = 0)
    nTotal = numpy.sum(rTotal)
    expCount = numpy.outer(cTotal, (rTotal / nTotal))
    # Calculate the Chi-Square statistics
    chiSq_stat = ((obsCount - expCount)**2 / expCount).to_numpy().sum()
    chiSq_DF = (xNCat - 1) * (yNCat - 1)
    if (chiSq_DF > 0):
        chiSq_pvalue = chi2.sf(chiSq_stat, chiSq_DF)
        cramerv = chiSq_stat / nTotal / (min(xNCat, yNCat) - 1.0)
        cramerv = numpy.sqrt(cramerv)
    else:
        chiSq_pvalue = numpy.NaN
        cramerv = numpy.NaN
    return cramerv

# %%
from scipy.stats import chi2, t

# %%
for a in lst:
    col = []
    col.append(a[0])
    col.append(a[1])
    df1 = df[col]
    cont_table = pandas.crosstab(index=df1[col[0]], columns=df[col[1]])
    c_stats = cramer_V(cont_table)
    print("The cramer's V of vaiables: ", col, " is: ", c_stats)
# Out:
# The cramer's V of vaiables:  ['Make', 'Origin']  is:  1.0
# The cramer's V of vaiables:  ['Make', 'Type']  is:  0.37019054302046817
# The cramer's V of vaiables:  ['Origin', 'Type']  is:  0.2041219966860013

# %% [markdown]
# **Pearson Correlation**

# %%
col = ['Horsepower', 'Length', 'Weight', 'Wheelbase']
a = combinations(col, 2)
lst = [a for a in a]
lst
# Out:
# [('Horsepower', 'Length'),
#  ('Horsepower', 'Weight'),
#  ('Horsepower', 'Wheelbase'),
#  ('Length', 'Weight'),
#  ('Length', 'Wheelbase'),
#  ('Weight', 'Wheelbase')]

# %%
df2 = data[col]
df2
# Out:
#      Horsepower  Length  Weight  Wheelbase
# 0           265     189    4451        106
# 1           200     172    2778        101
# 2           200     183    3230        105
# 3           270     186    3575        108
# 4           225     197    3880        115
# ..          ...     ...     ...        ...
# 423         197     186    3450        105
# 424         242     186    3450        105
# 425         268     190    3653        110
# 426         170     180    2822        101
# 427         208     186    3823        109
#
# [428 rows x 4 columns]

# %%
def pearson_corr(a):
    col = []
    col.append(a[0])
    col.append(a[1])
    df = df2[col]
    n = df.shape[0]
    xyCov = numpy.cov(df[col[0]], df[col[1]], ddof = 0)
    pCorr_sq = (xyCov[0,1] / xyCov[0,0]) *  (xyCov[0,1] / xyCov[1,1])
    pCorr = numpy.sqrt(pCorr_sq)
    return pCorr

# %%
for a in lst:
    p_corr = pearson_corr(a)
    print("The pearson correlation of vaiables: ", a, " is: ", p_corr)
# Out:
# The pearson correlation of vaiables:  ('Horsepower', 'Length')  is:  0.38155388132658946
# The pearson correlation of vaiables:  ('Horsepower', 'Weight')  is:  0.6307958167406753
# The pearson correlation of vaiables:  ('Horsepower', 'Wheelbase')  is:  0.38739778269895586
# The pearson correlation of vaiables:  ('Length', 'Weight')  is:  0.6900207109097168
# The pearson correlation of vaiables:  ('Length', 'Wheelbase')  is:  0.8891946668509833
# The pearson correlation of vaiables:  ('Weight', 'Wheelbase')  is:  0.760702758886357

# %% [markdown]
# **Eta-Squares**

# %%
from scipy.stats import chi2, f, t

# %%
def AnalysisOfVarianceTest(xCat, yCont):
   df = pandas.DataFrame(columns = ['x', 'y'])
   df['x'] = xCat
   df['y'] = yCont
   # Total Count and Sum of Squares
   totalCount = df['y'].count()
   totalSSQ = df['y'].var(ddof = 0) * totalCount
   # Within Group Count and Sums of Squares
   groupCount = df.groupby('x').count()
   groupSSQ = df.groupby('x').var(ddof = 0) * groupCount
   nGroup = groupCount.shape[0]
   withinSSQ = numpy.sum(groupSSQ.values)
   betweenSSQ = max(0.0, (totalSSQ - withinSSQ))
   if (totalSSQ > 0.0):
      etasq = betweenSSQ / totalSSQ
   else:
      etasq = numpy.NaN
       
   # Compute F statistics
   fDf1 = (nGroup - 1)
   fDf2 = (totalCount - nGroup)
   if (fDf1 > 0 and fDf2 > 0 and withinSSQ > 0.0):
      fStat = (betweenSSQ / fDf1) / (withinSSQ / fDf2)
      fSig = f.sf(fStat, fDf1, fDf2)
   else:
      fStat = numpy.NaN
      fSig = numpy.NaN
   outlist = [nGroup, fStat, fDf1, fDf2, fSig, etasq]
   return outlist[5]

# %%
col_cont = ['Horsepower', 'Length', 'Weight', 'Wheelbase']
col_cat = ['Make', 'Origin', 'Type']

# %%
comb = list(product(col_cat, col_cont))

# %%
for a in comb:
    col = []
    col.append(a[0])
    col.append(a[1])
    xCat = data[col[0]]
    yCont = data[col[1]]
    eta_sq = AnalysisOfVarianceTest(xCat, yCont)
    print("The Eta statistics of variables ", a, " is: ",eta_sq)
# Out:
# The Eta statistics of variables  ('Make', 'Horsepower')  is:  0.37937771353501754
# The Eta statistics of variables  ('Make', 'Length')  is:  0.33324569931120773
# The Eta statistics of variables  ('Make', 'Weight')  is:  0.2842022448303112
# The Eta statistics of variables  ('Make', 'Wheelbase')  is:  0.32275042061010345
# The Eta statistics of variables  ('Origin', 'Horsepower')  is:  0.11847771864192043
# The Eta statistics of variables  ('Origin', 'Length')  is:  0.1472784204176579
# The Eta statistics of variables  ('Origin', 'Weight')  is:  0.07027988993772898
# The Eta statistics of variables  ('Origin', 'Wheelbase')  is:  0.11418806981793002
# The Eta statistics of variables  ('Type', 'Horsepower')  is:  0.16684625872964987
# The Eta statistics of variables  ('Type', 'Length')  is:  0.23952601093607845
# The Eta statistics of variables  ('Type', 'Weight')  is:  0.2940396144123072
# The Eta statistics of variables  ('Type', 'Wheelbase')  is:  0.31833387676766267

# %% [markdown]
# **From the Cramer's V statistics, we can see the statistic of variables ('Make', 'Origin') equals to 1, which indicates the strong association between these two variables. For the Pearson Correlation, if we regard the correlation coefficient higher than 0.7 as high association, we can observe the strong association from two pairs of variables which are ('Length', 'Wheelbase') and ('Weight', 'Wheelbase'). From the Eta test, we can observe that the greatest statistic is 0.37937771 by variables ('Make', 'Horsepower'), which means about 38% of variance can be explained.**

# %% [markdown]
# ## Question 2

# %%
from sklearn.preprocessing import LabelEncoder

# %%
#Transfer the categorical variables by labelEncoder
labelencoder = LabelEncoder()
df['Make'] = labelencoder.fit_transform(data[['Make']])
df['Origin'] = labelencoder.fit_transform(data[['Origin']])
df['Type'] = labelencoder.fit_transform(data[['Type']])
df
# Out:
# E:\Anaconda\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# E:\Anaconda\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# E:\Anaconda\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#      Make  Origin  Type  Horsepower  Length  Weight  Wheelbase
# 0       0       0     1         265     189    4451        106
# 1       0       0     2         200     172    2778        101
# 2       0       0     2         200     183    3230        105
# 3       0       0     2         270     186    3575        108
# 4       0       0     2         225     197    3880        115
# ..    ...     ...   ...         ...     ...     ...        ...
# 423    37       1     2         197     186    3450        105
# 424    37       1     2         242     186    3450        105
# 425    37       1     2         268     190    3653        110
# 426    37       1     5         170     180    2822        101
# 427    37       1     5         208     186    3823        109
#
# [428 rows x 7 columns]

# %%
def SWEEPOperator (pDim, inputM, origDiag, sweepCol = None, tol = 1e-7):
    ''' Implement the SWEEP operator
    Parameter
    ---------
    pDim: dimension of matrix inputM, integer greater than one
    inputM: a square and symmetric matrix, numpy array
    origDiag: the original diagonal elements before any SWEEPing
    sweepCol: a list of columns numbers to SWEEP
    tol: singularity tolerance, positive real
    Return
    ------
    A: negative of a generalized inverse of input matrix
    aliasParam: a list of aliased rows/columns in input matrix
    nonAliasParam: a list of non-aliased rows/columns in input matrix
    '''
    if (sweepCol is None):
        sweepCol = range(pDim)
    aliasParam = []
    nonAliasParam = []
    A = numpy.copy(inputM)
    ANext = numpy.zeros((pDim,pDim))
    for k in sweepCol:
        Akk = A[k,k]
        pivot = tol * abs(origDiag[k])
        if (not numpy.isinf(Akk) and abs(Akk) >= pivot and pivot > 0.0):
            nonAliasParam.append(k)
            ANext = A - numpy.outer(A[:, k], A[k, :]) / Akk
            ANext[:, k] = A[:, k] / abs(Akk)
            ANext[k, :] = ANext[:, k]
            ANext[k, k] = -1.0 / Akk
        else:
            aliasParam.append(k)
            ANext[:,k] = numpy.zeros(pDim)
            ANext[k, :] = numpy.zeros(pDim)
        A = ANext
    return (A, aliasParam, nonAliasParam)
def LinearRegression (X, y):
    ''' Train a linear regression model
    Parameter
    ---------
    X: A Pandas DataFrame, rows are observations, columns are regressors
    y: A Pandas Series, rows are observations of the response variable
    Return
    ------
    A list of the following entities:
    1. b: an array of regression coefficient
    2. residual_SS: residual sum of squares
    3. XtX_Ginv: a generalized inverse of the XtX matrix
    4. aliasParam: a list of aliased rows/columns in input matrix
    5. nonAliasParam: a list of non-aliased rows/columns in input matrix
    '''
    # X: A Pandas DataFrame, rows are observations, columns are regressors
    # y: A Pandas Series, rows are observations of the response variable
    Z = X.join(y)
    n_sample = Z.shape[0]
    n_param = Z.shape[1] - 1
    ZtZ = Z.transpose().dot(Z)
    diag_ZtZ = numpy.diagonal(ZtZ)
    eps_double = numpy.finfo(numpy.float64).eps
    tol = numpy.sqrt(eps_double)
    ZtZ_transf, aliasParam, nonAliasParam = SWEEPOperator ((n_param+1), ZtZ, 
diag_ZtZ, sweepCol = range(n_param), tol = tol)
    b = ZtZ_transf[0:n_param, n_param]
    b[aliasParam] = 0.0
    XtX_Ginv = - ZtZ_transf[0:n_param, 0:n_param]
    XtX_Ginv[:, aliasParam] = 0.0
    XtX_Ginv[aliasParam, :] = 0.0
    residual_SS = ZtZ_transf[n_param, n_param]
    return ([b, residual_SS, XtX_Ginv, aliasParam, nonAliasParam])

# %%
# The FSig is the sixth element in each row of the FTest
def takeFSig(s):
    return s[6]
n_sample = data.shape[0]
X = df[['Make', 'Origin', 'Type', 'Horsepower', 'Length', 'Weight', 'Wheelbase']]
X.insert(0, 'Intercept', 1.0)
y = data['MPG_City']

# %%
enter_threshold = 0.05
q_show_diary = True
step_diary = []
var_in_model = ['Intercept']
# Step 0: Enter Intercept
result_list = LinearRegression(X[var_in_model], y)
m0 = len(result_list[4])
SSE0 = result_list[1]
step_diary.append([0, 'Intercept', SSE0, m0] + 4 * [numpy.nan])
# Forward Selection Steps
candidate = X.columns
candidate = candidate.to_list()
for iStep in range(len(candidate)):
    FTest = []
    for pred in candidate:
        work_list = var_in_model.copy()
        work_list.append(pred)
        result_list = LinearRegression(X[work_list], y)
        m1 = len(result_list[4])
        SSE1 = result_list[1]
        df_numer = m1 - m0
        df_denom = n_sample - m1
        if (df_numer > 0 and df_denom > 0):
            FStat = ((SSE0 - SSE1) / df_numer) / (SSE1 / df_denom)
            FSig = f.sf(FStat, df_numer, df_denom)
            FTest.append([pred, SSE1, m1, FStat, df_numer, df_denom, FSig])
    # Show F Test results for the current step
    if (q_show_diary):
        print('\n===== F Test Results for the Current Forward Step =====')
        print('Step Number: ', iStep)
        print('Step Diary:')
        print('[Variable Candidate | Residual Sum of Squares | N Non-Aliased Parameters | F Stat | F DF1 | F DF2 | F Sig]')
        for row in FTest:
            print(row)
    FTest.sort(key = takeFSig, reverse = False)
    FSig = takeFSig(FTest[0])
    if (FSig <= enter_threshold):
        enter_var = FTest[0][0]
        SSE0 = FTest[0][1]
        m0 = FTest[0][2]
        step_diary.append([iStep+1] + FTest[0])
        var_in_model.append(enter_var)
        candidate.remove(enter_var)
    else:
        break
forward_summary = pandas.DataFrame(step_diary, columns = ['Step', 'Variable Entered', 'Residual Sum of Squares', 'N Non-Aliased Parameters', 'F Stat', 'F DF1','F DF2', 'F Sig'])
# Out:
# ===== F Test Results for the Current Forward Step =====
# Step Number:  0
# Step Diary:
# [Variable Candidate | Residual Sum of Squares | N Non-Aliased Parameters | F Stat | F DF1 | F DF2 | F Sig]
# ['Make', 11402.98265660611, 2, 11.709615912372932, 1, 426, 0.0006818602217303737]
# ['Origin', 11041.993129835388, 2, 26.01940448525872, 1, 426, 5.098337455842681e-07]
# ['Type', 11678.895069532251, 2, 1.3687818207627174, 1, 426, 0.24267542026011696]
# ['Horsepower', 6351.214305686575, 2, 359.8647053382581, 1, 426, 1.2899063768087322e-58]
# ['Length', 8769.404017767567, 2, 143.1601332047103, 1, 426, 1.2106528588598324e-28]
# ['Weight', 5335.730401687142, 2, 509.4286635809614, 1, 426, 9.058801587355108e-75]
# ['Wheelbase', 8701.353690708083, 2, 147.61134098116926, 1, 426, 2.2778064426503926e-29]
#
# ===== F Test Results for the Current Forward Step =====
# Step Number:  1
# Step Diary:
# [Variable Candidate | Residual Sum of Squares | N Non-Aliased Parameters | F Stat | F DF1 | F DF2 | F Sig]
# ['Make', 5307.91733012613, 3, 2.2269667514112053, 1, 425, 0.13636177806849098]
# ['Origin', 5299.655309969346, 3, 2.893002107367663, 1, 425, 0.08969649040562495]
# ['Type', 5089.341487859362, 3, 20.575410124591777, 1, 425, 7.468459789371735e-06]
# ['Horsepower', 4467.790547901631, 3, 82.56305525156951, 1, 425, 3.91540892560443e-18]
# ['Length', 5334.409397499521, 3, 0.10524628649650716, 1, 425, 0.7457820818048477]
# ['Wheelbase', 5254.37459456236, 3, 6.580463080004762, 1, 425, 0.010652590873070503]
#
# ===== F Test Results for the Current Forward Step =====
# Step Number:  2
# Step Diary:
# [Variable Candidate | Residual Sum of Squares | N Non-Aliased Parameters | F Stat | F DF1 | F DF2 | F Sig]
# ['Make', 4454.955362135424, 4, 1.2215877203005074, 1, 424, 0.2696760513943405]
# ['Origin', 4420.013385666142, 4, 4.583134714827137, 1, 424, 0.03285778396142617]
# ['Type', 4339.303836586917, 4, 12.554632643628999, 1, 424, 0.0004391467021512636]
# ['Length', 4464.98264470401, 4, 0.2666417880040734, 1, 424, 0.6058626347624214]
# ['Wheelbase', 4454.288377946746, 4, 1.285260309865766, 1, 424, 0.257563847963612]
#
# ===== F Test Results for the Current Forward Step =====
# Step Number:  3
# Step Diary:
# [Variable Candidate | Residual Sum of Squares | N Non-Aliased Parameters | F Stat | F DF1 | F DF2 | F Sig]
# ['Make', 4323.185901101629, 5, 1.5770514769072659, 1, 423, 0.20987911657335198]
# ['Origin', 4299.039610050952, 5, 3.9617610837763704, 1, 423, 0.04718810766929923]
# ['Length', 4339.290196585499, 5, 0.0013296461721700016, 1, 423, 0.9709293348689463]
# ['Wheelbase', 4308.727752871613, 5, 3.0017406885254467, 1, 423, 0.0839039862368399]
#
# ===== F Test Results for the Current Forward Step =====
# Step Number:  4
# Step Diary:
# [Variable Candidate | Residual Sum of Squares | N Non-Aliased Parameters | F Stat | F DF1 | F DF2 | F Sig]
# ['Make', 4295.6146111921435, 6, 0.3364709475220512, 1, 422, 0.5621829500196787]
# ['Length', 4297.546457343247, 6, 0.1466209728983586, 1, 422, 0.7019784182145142]
# ['Wheelbase', 4253.191309341122, 6, 4.549050699190307, 1, 422, 0.03351349028806664]
#
# ===== F Test Results for the Current Forward Step =====
# Step Number:  5
# Step Diary:
# [Variable Candidate | Residual Sum of Squares | N Non-Aliased Parameters | F Stat | F DF1 | F DF2 | F Sig]
# ['Make', 4246.696920024407, 7, 0.6438269445236372, 1, 421, 0.42278109841970224]
# ['Length', 4216.436869507971, 7, 3.6698330008584406, 1, 421, 0.0560827929263456]

# %% [markdown]
# **According to the final result, we have our final model MPG_City ~ Intercept + Origin + Type + Horsepower + Weight + Wheelbase.**

# %%
def tss(a):
    m = a.mean()
    n = 0
    for i in a:
        n += ((i-m)**2)
    return (n)

# %%
X_1 = df[['Origin', 'Type', 'Horsepower', 'Weight', 'Wheelbase']]
X_1.insert(0, 'Intercept', 1.0)
X_1
# Out:
#      Intercept  Origin  Type  Horsepower  Weight  Wheelbase
# 0          1.0       0     1         265    4451        106
# 1          1.0       0     2         200    2778        101
# 2          1.0       0     2         200    3230        105
# 3          1.0       0     2         270    3575        108
# 4          1.0       0     2         225    3880        115
# ..         ...     ...   ...         ...     ...        ...
# 423        1.0       1     2         197    3450        105
# 424        1.0       1     2         242    3450        105
# 425        1.0       1     2         268    3653        110
# 426        1.0       1     5         170    2822        101
# 427        1.0       1     5         208    3823        109
#
# [428 rows x 6 columns]

# %%
result_list = LinearRegression(X_1, y)

# %%
residual_SS = result_list[1]
r_sq = 1 - (residual_SS/tss(y))
r_sq
# Out:
# 0.636988849342762

# %% [markdown]
# **The R-squared is 0.636988849342762**

# %% [markdown]
# ## Question 3

# %%
def all_subsets(v):
    return chain(*map(lambda x: combinations(v, x), range(0, len(v)+1)))
values = ['Make', 'Origin', 'Type', 'Horsepower', 'Length', 'Weight', 'Wheelbase']
subset = pandas.DataFrame(all_subsets(values))
subset
# Out:
#               0       1           2           3       4          5          6
# 0          None    None        None        None    None       None       None
# 1          Make    None        None        None    None       None       None
# 2        Origin    None        None        None    None       None       None
# 3          Type    None        None        None    None       None       None
# 4    Horsepower    None        None        None    None       None       None
# ..          ...     ...         ...         ...     ...        ...        ...
# 123        Make  Origin        Type      Length  Weight  Wheelbase       None
# 124        Make  Origin  Horsepower      Length  Weight  Wheelbase       None
# 125        Make    Type  Horsepower      Length  Weight  Wheelbase       None
# 126      Origin    Type  Horsepower      Length  Weight  Wheelbase       None
# 127        Make  Origin        Type  Horsepower  Length     Weight  Wheelbase
#
# [128 rows x 7 columns]

# %%
len(subset.index)
# Out:
# 128

# %%
import math

# %%
aic_lst = []
r_sq_lst = []
permu_lst = []
for i in subset.index:
    lst_var = subset.loc[i].to_list()
    subset_var = []
    for val in lst_var:
        if val != None :
            subset_var.append(val)
    permu_lst.append(subset_var)
    X_2 = df[subset_var]
    n_sample1 = X_2.shape[0]
    y = data['MPG_City']
    X_2.insert(0, 'Intercept', 1.0)
    return_list1 = LinearRegression(X_2, y)
    residual_SS1 = return_list1[1]
    no_of_nonaliased = len(return_list1[4])
    pop_var = residual_SS1/n_sample1
    AIC = n_sample * math.log(pop_var) + 2.0 * no_of_nonaliased
    r_sq = 1 - (residual_SS1/tss(y))
    aic_lst.append(AIC)
    r_sq_lst.append(r_sq)

# %%
dff = pandas.DataFrame(aic_lst, columns=['AIC'])
dff['R-Squared'] = r_sq_lst
order_lst = [x for x in range(128)]
dff['Subset_order'] = order_lst

# %%
dff.sort_values(by=['AIC'])
# Out:
#              AIC     R-Squared  Subset_order
# 126   993.102435  6.401259e-01           126
# 127   993.933856  6.411071e-01           127
# 125   994.564468  6.388944e-01           125
# 116   994.817119  6.369888e-01           116
# 119   995.684644  6.362523e-01           119
# ..           ...           ...           ...
# 14   1395.852497  6.040325e-02            14
# 1    1408.913014  2.675202e-02             1
# 9    1409.092271  3.088349e-02             9
# 0    1418.518819 -2.664535e-15             0
# 3    1419.145815  3.202812e-03             3
#
# [128 rows x 3 columns]

# %%
subset.loc[126]
# Out:
# 0        Origin
# 1          Type
# 2    Horsepower
# 3        Length
# 4        Weight
# 5     Wheelbase
# 6          None
# Name: 126, dtype: object

# %% [markdown]
# **Save to Excel**

# %%
file_name = 'R-squared.xlsx'
  
# saving the excel
dff.to_excel(file_name)

# %% [markdown]
# ## Question 4

# %%
dff
# Out:
#              AIC     R-Squared  Subset_order
# 0    1418.518819 -2.664535e-15             0
# 1    1408.913014  2.675202e-02             1
# 2    1395.144512  5.756258e-02             2
# 3    1419.145815  3.202812e-03             3
# 4    1158.435030  4.579220e-01             4
# ..           ...           ...           ...
# 123  1049.644141  5.893008e-01           123
# 124  1006.274599  6.288781e-01           124
# 125   994.564468  6.388944e-01           125
# 126   993.102435  6.401259e-01           126
# 127   993.933856  6.411071e-01           127
#
# [128 rows x 3 columns]

# %%
dff['permu'] = permu_lst
dff
# Out:
#              AIC     R-Squared  Subset_order  \
# 0    1418.518819 -2.664535e-15             0
# 1    1408.913014  2.675202e-02             1
# 2    1395.144512  5.756258e-02             2
# 3    1419.145815  3.202812e-03             3
# 4    1158.435030  4.579220e-01             4
# ..           ...           ...           ...
# 123  1049.644141  5.893008e-01           123
# 124  1006.274599  6.288781e-01           124
# 125   994.564468  6.388944e-01           125
# 126   993.102435  6.401259e-01           126
# 127   993.933856  6.411071e-01           127
#
#                                                  permu
# 0                                                   []
# 1                                               [Make]
# 2                                             [Origin]
# 3                                               [Type]
# 4                                         [Horsepower]
# ..                                                 ...
# 123    [Make, Origin, Type, Length, Weight, Wheelbase]
# 124  [Make, Origin, Horsepower, Length, Weight, Whe...
# 125  [Make, Type, Horsepower, Length, Weight, Wheel...
# 126  [Origin, Type, Horsepower, Length, Weight, Whe...
# 127  [Make, Origin, Type, Horsepower, Length, Weigh...
#
# [128 rows x 4 columns]

# %%
from itertools import permutations
p = permutations(['Make', 'Origin', 'Type', 'Horsepower', 'Length', 'Weight', 'Wheelbase'])
perm_index = []
for i in p:
    perm_index.append(list(i))
perm_index
# Out:
# [['Make', 'Origin', 'Type', 'Horsepower', 'Length', 'Weight', 'Wheelbase'],
#  ['Make', 'Origin', 'Type', 'Horsepower', 'Length', 'Wheelbase', 'Weight'],
#  ['Make', 'Origin', 'Type', 'Horsepower', 'Weight', 'Length', 'Wheelbase'],
#  ['Make', 'Origin', 'Type', 'Horsepower', 'Weight', 'Wheelbase', 'Length'],
#  ['Make', 'Origin', 'Type', 'Horsepower', 'Wheelbase', 'Length', 'Weight'],
#  ['Make', 'Origin', 'Type', 'Horsepower', 'Wheelbase', 'Weight', 'Length'],
#  ['Make', 'Origin', 'Type', 'Length', 'Horsepower', 'Weight', 'Wheelbase'],
#  ['Make', 'Origin', 'Type', 'Length', 'Horsepower', 'Wheelbase', 'Weight'],
#  ['Make', 'Origin', 'Type', 'Length', 'Weight', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Origin', 'Type', 'Length', 'Weight', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Origin', 'Type', 'Length', 'Wheelbase', 'Horsepower', 'Weight'],
#  ['Make', 'Origin', 'Type', 'Length', 'Wheelbase', 'Weight', 'Horsepower'],
#  ['Make', 'Origin', 'Type', 'Weight', 'Horsepower', 'Length', 'Wheelbase'],
#  ['Make', 'Origin', 'Type', 'Weight', 'Horsepower', 'Wheelbase', 'Length'],
#  ['Make', 'Origin', 'Type', 'Weight', 'Length', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Origin', 'Type', 'Weight', 'Length', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Origin', 'Type', 'Weight', 'Wheelbase', 'Horsepower', 'Length'],
#  ['Make', 'Origin', 'Type', 'Weight', 'Wheelbase', 'Length', 'Horsepower'],
#  ['Make', 'Origin', 'Type', 'Wheelbase', 'Horsepower', 'Length', 'Weight'],
#  ['Make', 'Origin', 'Type', 'Wheelbase', 'Horsepower', 'Weight', 'Length'],
#  ['Make', 'Origin', 'Type', 'Wheelbase', 'Length', 'Horsepower', 'Weight'],
#  ['Make', 'Origin', 'Type', 'Wheelbase', 'Length', 'Weight', 'Horsepower'],
#  ['Make', 'Origin', 'Type', 'Wheelbase', 'Weight', 'Horsepower', 'Length'],
#  ['Make', 'Origin', 'Type', 'Wheelbase', 'Weight', 'Length', 'Horsepower'],
#  ['Make', 'Origin', 'Horsepower', 'Type', 'Length', 'Weight', 'Wheelbase'],
#  ['Make', 'Origin', 'Horsepower', 'Type', 'Length', 'Wheelbase', 'Weight'],
#  ['Make', 'Origin', 'Horsepower', 'Type', 'Weight', 'Length', 'Wheelbase'],
#  ['Make', 'Origin', 'Horsepower', 'Type', 'Weight', 'Wheelbase', 'Length'],
#  ['Make', 'Origin', 'Horsepower', 'Type', 'Wheelbase', 'Length', 'Weight'],
#  ['Make', 'Origin', 'Horsepower', 'Type', 'Wheelbase', 'Weight', 'Length'],
#  ['Make', 'Origin', 'Horsepower', 'Length', 'Type', 'Weight', 'Wheelbase'],
#  ['Make', 'Origin', 'Horsepower', 'Length', 'Type', 'Wheelbase', 'Weight'],
#  ['Make', 'Origin', 'Horsepower', 'Length', 'Weight', 'Type', 'Wheelbase'],
#  ['Make', 'Origin', 'Horsepower', 'Length', 'Weight', 'Wheelbase', 'Type'],
#  ['Make', 'Origin', 'Horsepower', 'Length', 'Wheelbase', 'Type', 'Weight'],
#  ['Make', 'Origin', 'Horsepower', 'Length', 'Wheelbase', 'Weight', 'Type'],
#  ['Make', 'Origin', 'Horsepower', 'Weight', 'Type', 'Length', 'Wheelbase'],
#  ['Make', 'Origin', 'Horsepower', 'Weight', 'Type', 'Wheelbase', 'Length'],
#  ['Make', 'Origin', 'Horsepower', 'Weight', 'Length', 'Type', 'Wheelbase'],
#  ['Make', 'Origin', 'Horsepower', 'Weight', 'Length', 'Wheelbase', 'Type'],
#  ['Make', 'Origin', 'Horsepower', 'Weight', 'Wheelbase', 'Type', 'Length'],
#  ['Make', 'Origin', 'Horsepower', 'Weight', 'Wheelbase', 'Length', 'Type'],
#  ['Make', 'Origin', 'Horsepower', 'Wheelbase', 'Type', 'Length', 'Weight'],
#  ['Make', 'Origin', 'Horsepower', 'Wheelbase', 'Type', 'Weight', 'Length'],
#  ['Make', 'Origin', 'Horsepower', 'Wheelbase', 'Length', 'Type', 'Weight'],
#  ['Make', 'Origin', 'Horsepower', 'Wheelbase', 'Length', 'Weight', 'Type'],
#  ['Make', 'Origin', 'Horsepower', 'Wheelbase', 'Weight', 'Type', 'Length'],
#  ['Make', 'Origin', 'Horsepower', 'Wheelbase', 'Weight', 'Length', 'Type'],
#  ['Make', 'Origin', 'Length', 'Type', 'Horsepower', 'Weight', 'Wheelbase'],
#  ['Make', 'Origin', 'Length', 'Type', 'Horsepower', 'Wheelbase', 'Weight'],
#  ['Make', 'Origin', 'Length', 'Type', 'Weight', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Origin', 'Length', 'Type', 'Weight', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Origin', 'Length', 'Type', 'Wheelbase', 'Horsepower', 'Weight'],
#  ['Make', 'Origin', 'Length', 'Type', 'Wheelbase', 'Weight', 'Horsepower'],
#  ['Make', 'Origin', 'Length', 'Horsepower', 'Type', 'Weight', 'Wheelbase'],
#  ['Make', 'Origin', 'Length', 'Horsepower', 'Type', 'Wheelbase', 'Weight'],
#  ['Make', 'Origin', 'Length', 'Horsepower', 'Weight', 'Type', 'Wheelbase'],
#  ['Make', 'Origin', 'Length', 'Horsepower', 'Weight', 'Wheelbase', 'Type'],
#  ['Make', 'Origin', 'Length', 'Horsepower', 'Wheelbase', 'Type', 'Weight'],
#  ['Make', 'Origin', 'Length', 'Horsepower', 'Wheelbase', 'Weight', 'Type'],
#  ['Make', 'Origin', 'Length', 'Weight', 'Type', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Origin', 'Length', 'Weight', 'Type', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Origin', 'Length', 'Weight', 'Horsepower', 'Type', 'Wheelbase'],
#  ['Make', 'Origin', 'Length', 'Weight', 'Horsepower', 'Wheelbase', 'Type'],
#  ['Make', 'Origin', 'Length', 'Weight', 'Wheelbase', 'Type', 'Horsepower'],
#  ['Make', 'Origin', 'Length', 'Weight', 'Wheelbase', 'Horsepower', 'Type'],
#  ['Make', 'Origin', 'Length', 'Wheelbase', 'Type', 'Horsepower', 'Weight'],
#  ['Make', 'Origin', 'Length', 'Wheelbase', 'Type', 'Weight', 'Horsepower'],
#  ['Make', 'Origin', 'Length', 'Wheelbase', 'Horsepower', 'Type', 'Weight'],
#  ['Make', 'Origin', 'Length', 'Wheelbase', 'Horsepower', 'Weight', 'Type'],
#  ['Make', 'Origin', 'Length', 'Wheelbase', 'Weight', 'Type', 'Horsepower'],
#  ['Make', 'Origin', 'Length', 'Wheelbase', 'Weight', 'Horsepower', 'Type'],
#  ['Make', 'Origin', 'Weight', 'Type', 'Horsepower', 'Length', 'Wheelbase'],
#  ['Make', 'Origin', 'Weight', 'Type', 'Horsepower', 'Wheelbase', 'Length'],
#  ['Make', 'Origin', 'Weight', 'Type', 'Length', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Origin', 'Weight', 'Type', 'Length', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Origin', 'Weight', 'Type', 'Wheelbase', 'Horsepower', 'Length'],
#  ['Make', 'Origin', 'Weight', 'Type', 'Wheelbase', 'Length', 'Horsepower'],
#  ['Make', 'Origin', 'Weight', 'Horsepower', 'Type', 'Length', 'Wheelbase'],
#  ['Make', 'Origin', 'Weight', 'Horsepower', 'Type', 'Wheelbase', 'Length'],
#  ['Make', 'Origin', 'Weight', 'Horsepower', 'Length', 'Type', 'Wheelbase'],
#  ['Make', 'Origin', 'Weight', 'Horsepower', 'Length', 'Wheelbase', 'Type'],
#  ['Make', 'Origin', 'Weight', 'Horsepower', 'Wheelbase', 'Type', 'Length'],
#  ['Make', 'Origin', 'Weight', 'Horsepower', 'Wheelbase', 'Length', 'Type'],
#  ['Make', 'Origin', 'Weight', 'Length', 'Type', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Origin', 'Weight', 'Length', 'Type', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Origin', 'Weight', 'Length', 'Horsepower', 'Type', 'Wheelbase'],
#  ['Make', 'Origin', 'Weight', 'Length', 'Horsepower', 'Wheelbase', 'Type'],
#  ['Make', 'Origin', 'Weight', 'Length', 'Wheelbase', 'Type', 'Horsepower'],
#  ['Make', 'Origin', 'Weight', 'Length', 'Wheelbase', 'Horsepower', 'Type'],
#  ['Make', 'Origin', 'Weight', 'Wheelbase', 'Type', 'Horsepower', 'Length'],
#  ['Make', 'Origin', 'Weight', 'Wheelbase', 'Type', 'Length', 'Horsepower'],
#  ['Make', 'Origin', 'Weight', 'Wheelbase', 'Horsepower', 'Type', 'Length'],
#  ['Make', 'Origin', 'Weight', 'Wheelbase', 'Horsepower', 'Length', 'Type'],
#  ['Make', 'Origin', 'Weight', 'Wheelbase', 'Length', 'Type', 'Horsepower'],
#  ['Make', 'Origin', 'Weight', 'Wheelbase', 'Length', 'Horsepower', 'Type'],
#  ['Make', 'Origin', 'Wheelbase', 'Type', 'Horsepower', 'Length', 'Weight'],
#  ['Make', 'Origin', 'Wheelbase', 'Type', 'Horsepower', 'Weight', 'Length'],
#  ['Make', 'Origin', 'Wheelbase', 'Type', 'Length', 'Horsepower', 'Weight'],
#  ['Make', 'Origin', 'Wheelbase', 'Type', 'Length', 'Weight', 'Horsepower'],
#  ['Make', 'Origin', 'Wheelbase', 'Type', 'Weight', 'Horsepower', 'Length'],
#  ['Make', 'Origin', 'Wheelbase', 'Type', 'Weight', 'Length', 'Horsepower'],
#  ['Make', 'Origin', 'Wheelbase', 'Horsepower', 'Type', 'Length', 'Weight'],
#  ['Make', 'Origin', 'Wheelbase', 'Horsepower', 'Type', 'Weight', 'Length'],
#  ['Make', 'Origin', 'Wheelbase', 'Horsepower', 'Length', 'Type', 'Weight'],
#  ['Make', 'Origin', 'Wheelbase', 'Horsepower', 'Length', 'Weight', 'Type'],
#  ['Make', 'Origin', 'Wheelbase', 'Horsepower', 'Weight', 'Type', 'Length'],
#  ['Make', 'Origin', 'Wheelbase', 'Horsepower', 'Weight', 'Length', 'Type'],
#  ['Make', 'Origin', 'Wheelbase', 'Length', 'Type', 'Horsepower', 'Weight'],
#  ['Make', 'Origin', 'Wheelbase', 'Length', 'Type', 'Weight', 'Horsepower'],
#  ['Make', 'Origin', 'Wheelbase', 'Length', 'Horsepower', 'Type', 'Weight'],
#  ['Make', 'Origin', 'Wheelbase', 'Length', 'Horsepower', 'Weight', 'Type'],
#  ['Make', 'Origin', 'Wheelbase', 'Length', 'Weight', 'Type', 'Horsepower'],
#  ['Make', 'Origin', 'Wheelbase', 'Length', 'Weight', 'Horsepower', 'Type'],
#  ['Make', 'Origin', 'Wheelbase', 'Weight', 'Type', 'Horsepower', 'Length'],
#  ['Make', 'Origin', 'Wheelbase', 'Weight', 'Type', 'Length', 'Horsepower'],
#  ['Make', 'Origin', 'Wheelbase', 'Weight', 'Horsepower', 'Type', 'Length'],
#  ['Make', 'Origin', 'Wheelbase', 'Weight', 'Horsepower', 'Length', 'Type'],
#  ['Make', 'Origin', 'Wheelbase', 'Weight', 'Length', 'Type', 'Horsepower'],
#  ['Make', 'Origin', 'Wheelbase', 'Weight', 'Length', 'Horsepower', 'Type'],
#  ['Make', 'Type', 'Origin', 'Horsepower', 'Length', 'Weight', 'Wheelbase'],
#  ['Make', 'Type', 'Origin', 'Horsepower', 'Length', 'Wheelbase', 'Weight'],
#  ['Make', 'Type', 'Origin', 'Horsepower', 'Weight', 'Length', 'Wheelbase'],
#  ['Make', 'Type', 'Origin', 'Horsepower', 'Weight', 'Wheelbase', 'Length'],
#  ['Make', 'Type', 'Origin', 'Horsepower', 'Wheelbase', 'Length', 'Weight'],
#  ['Make', 'Type', 'Origin', 'Horsepower', 'Wheelbase', 'Weight', 'Length'],
#  ['Make', 'Type', 'Origin', 'Length', 'Horsepower', 'Weight', 'Wheelbase'],
#  ['Make', 'Type', 'Origin', 'Length', 'Horsepower', 'Wheelbase', 'Weight'],
#  ['Make', 'Type', 'Origin', 'Length', 'Weight', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Type', 'Origin', 'Length', 'Weight', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Type', 'Origin', 'Length', 'Wheelbase', 'Horsepower', 'Weight'],
#  ['Make', 'Type', 'Origin', 'Length', 'Wheelbase', 'Weight', 'Horsepower'],
#  ['Make', 'Type', 'Origin', 'Weight', 'Horsepower', 'Length', 'Wheelbase'],
#  ['Make', 'Type', 'Origin', 'Weight', 'Horsepower', 'Wheelbase', 'Length'],
#  ['Make', 'Type', 'Origin', 'Weight', 'Length', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Type', 'Origin', 'Weight', 'Length', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Type', 'Origin', 'Weight', 'Wheelbase', 'Horsepower', 'Length'],
#  ['Make', 'Type', 'Origin', 'Weight', 'Wheelbase', 'Length', 'Horsepower'],
#  ['Make', 'Type', 'Origin', 'Wheelbase', 'Horsepower', 'Length', 'Weight'],
#  ['Make', 'Type', 'Origin', 'Wheelbase', 'Horsepower', 'Weight', 'Length'],
#  ['Make', 'Type', 'Origin', 'Wheelbase', 'Length', 'Horsepower', 'Weight'],
#  ['Make', 'Type', 'Origin', 'Wheelbase', 'Length', 'Weight', 'Horsepower'],
#  ['Make', 'Type', 'Origin', 'Wheelbase', 'Weight', 'Horsepower', 'Length'],
#  ['Make', 'Type', 'Origin', 'Wheelbase', 'Weight', 'Length', 'Horsepower'],
#  ['Make', 'Type', 'Horsepower', 'Origin', 'Length', 'Weight', 'Wheelbase'],
#  ['Make', 'Type', 'Horsepower', 'Origin', 'Length', 'Wheelbase', 'Weight'],
#  ['Make', 'Type', 'Horsepower', 'Origin', 'Weight', 'Length', 'Wheelbase'],
#  ['Make', 'Type', 'Horsepower', 'Origin', 'Weight', 'Wheelbase', 'Length'],
#  ['Make', 'Type', 'Horsepower', 'Origin', 'Wheelbase', 'Length', 'Weight'],
#  ['Make', 'Type', 'Horsepower', 'Origin', 'Wheelbase', 'Weight', 'Length'],
#  ['Make', 'Type', 'Horsepower', 'Length', 'Origin', 'Weight', 'Wheelbase'],
#  ['Make', 'Type', 'Horsepower', 'Length', 'Origin', 'Wheelbase', 'Weight'],
#  ['Make', 'Type', 'Horsepower', 'Length', 'Weight', 'Origin', 'Wheelbase'],
#  ['Make', 'Type', 'Horsepower', 'Length', 'Weight', 'Wheelbase', 'Origin'],
#  ['Make', 'Type', 'Horsepower', 'Length', 'Wheelbase', 'Origin', 'Weight'],
#  ['Make', 'Type', 'Horsepower', 'Length', 'Wheelbase', 'Weight', 'Origin'],
#  ['Make', 'Type', 'Horsepower', 'Weight', 'Origin', 'Length', 'Wheelbase'],
#  ['Make', 'Type', 'Horsepower', 'Weight', 'Origin', 'Wheelbase', 'Length'],
#  ['Make', 'Type', 'Horsepower', 'Weight', 'Length', 'Origin', 'Wheelbase'],
#  ['Make', 'Type', 'Horsepower', 'Weight', 'Length', 'Wheelbase', 'Origin'],
#  ['Make', 'Type', 'Horsepower', 'Weight', 'Wheelbase', 'Origin', 'Length'],
#  ['Make', 'Type', 'Horsepower', 'Weight', 'Wheelbase', 'Length', 'Origin'],
#  ['Make', 'Type', 'Horsepower', 'Wheelbase', 'Origin', 'Length', 'Weight'],
#  ['Make', 'Type', 'Horsepower', 'Wheelbase', 'Origin', 'Weight', 'Length'],
#  ['Make', 'Type', 'Horsepower', 'Wheelbase', 'Length', 'Origin', 'Weight'],
#  ['Make', 'Type', 'Horsepower', 'Wheelbase', 'Length', 'Weight', 'Origin'],
#  ['Make', 'Type', 'Horsepower', 'Wheelbase', 'Weight', 'Origin', 'Length'],
#  ['Make', 'Type', 'Horsepower', 'Wheelbase', 'Weight', 'Length', 'Origin'],
#  ['Make', 'Type', 'Length', 'Origin', 'Horsepower', 'Weight', 'Wheelbase'],
#  ['Make', 'Type', 'Length', 'Origin', 'Horsepower', 'Wheelbase', 'Weight'],
#  ['Make', 'Type', 'Length', 'Origin', 'Weight', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Type', 'Length', 'Origin', 'Weight', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Type', 'Length', 'Origin', 'Wheelbase', 'Horsepower', 'Weight'],
#  ['Make', 'Type', 'Length', 'Origin', 'Wheelbase', 'Weight', 'Horsepower'],
#  ['Make', 'Type', 'Length', 'Horsepower', 'Origin', 'Weight', 'Wheelbase'],
#  ['Make', 'Type', 'Length', 'Horsepower', 'Origin', 'Wheelbase', 'Weight'],
#  ['Make', 'Type', 'Length', 'Horsepower', 'Weight', 'Origin', 'Wheelbase'],
#  ['Make', 'Type', 'Length', 'Horsepower', 'Weight', 'Wheelbase', 'Origin'],
#  ['Make', 'Type', 'Length', 'Horsepower', 'Wheelbase', 'Origin', 'Weight'],
#  ['Make', 'Type', 'Length', 'Horsepower', 'Wheelbase', 'Weight', 'Origin'],
#  ['Make', 'Type', 'Length', 'Weight', 'Origin', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Type', 'Length', 'Weight', 'Origin', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Type', 'Length', 'Weight', 'Horsepower', 'Origin', 'Wheelbase'],
#  ['Make', 'Type', 'Length', 'Weight', 'Horsepower', 'Wheelbase', 'Origin'],
#  ['Make', 'Type', 'Length', 'Weight', 'Wheelbase', 'Origin', 'Horsepower'],
#  ['Make', 'Type', 'Length', 'Weight', 'Wheelbase', 'Horsepower', 'Origin'],
#  ['Make', 'Type', 'Length', 'Wheelbase', 'Origin', 'Horsepower', 'Weight'],
#  ['Make', 'Type', 'Length', 'Wheelbase', 'Origin', 'Weight', 'Horsepower'],
#  ['Make', 'Type', 'Length', 'Wheelbase', 'Horsepower', 'Origin', 'Weight'],
#  ['Make', 'Type', 'Length', 'Wheelbase', 'Horsepower', 'Weight', 'Origin'],
#  ['Make', 'Type', 'Length', 'Wheelbase', 'Weight', 'Origin', 'Horsepower'],
#  ['Make', 'Type', 'Length', 'Wheelbase', 'Weight', 'Horsepower', 'Origin'],
#  ['Make', 'Type', 'Weight', 'Origin', 'Horsepower', 'Length', 'Wheelbase'],
#  ['Make', 'Type', 'Weight', 'Origin', 'Horsepower', 'Wheelbase', 'Length'],
#  ['Make', 'Type', 'Weight', 'Origin', 'Length', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Type', 'Weight', 'Origin', 'Length', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Type', 'Weight', 'Origin', 'Wheelbase', 'Horsepower', 'Length'],
#  ['Make', 'Type', 'Weight', 'Origin', 'Wheelbase', 'Length', 'Horsepower'],
#  ['Make', 'Type', 'Weight', 'Horsepower', 'Origin', 'Length', 'Wheelbase'],
#  ['Make', 'Type', 'Weight', 'Horsepower', 'Origin', 'Wheelbase', 'Length'],
#  ['Make', 'Type', 'Weight', 'Horsepower', 'Length', 'Origin', 'Wheelbase'],
#  ['Make', 'Type', 'Weight', 'Horsepower', 'Length', 'Wheelbase', 'Origin'],
#  ['Make', 'Type', 'Weight', 'Horsepower', 'Wheelbase', 'Origin', 'Length'],
#  ['Make', 'Type', 'Weight', 'Horsepower', 'Wheelbase', 'Length', 'Origin'],
#  ['Make', 'Type', 'Weight', 'Length', 'Origin', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Type', 'Weight', 'Length', 'Origin', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Type', 'Weight', 'Length', 'Horsepower', 'Origin', 'Wheelbase'],
#  ['Make', 'Type', 'Weight', 'Length', 'Horsepower', 'Wheelbase', 'Origin'],
#  ['Make', 'Type', 'Weight', 'Length', 'Wheelbase', 'Origin', 'Horsepower'],
#  ['Make', 'Type', 'Weight', 'Length', 'Wheelbase', 'Horsepower', 'Origin'],
#  ['Make', 'Type', 'Weight', 'Wheelbase', 'Origin', 'Horsepower', 'Length'],
#  ['Make', 'Type', 'Weight', 'Wheelbase', 'Origin', 'Length', 'Horsepower'],
#  ['Make', 'Type', 'Weight', 'Wheelbase', 'Horsepower', 'Origin', 'Length'],
#  ['Make', 'Type', 'Weight', 'Wheelbase', 'Horsepower', 'Length', 'Origin'],
#  ['Make', 'Type', 'Weight', 'Wheelbase', 'Length', 'Origin', 'Horsepower'],
#  ['Make', 'Type', 'Weight', 'Wheelbase', 'Length', 'Horsepower', 'Origin'],
#  ['Make', 'Type', 'Wheelbase', 'Origin', 'Horsepower', 'Length', 'Weight'],
#  ['Make', 'Type', 'Wheelbase', 'Origin', 'Horsepower', 'Weight', 'Length'],
#  ['Make', 'Type', 'Wheelbase', 'Origin', 'Length', 'Horsepower', 'Weight'],
#  ['Make', 'Type', 'Wheelbase', 'Origin', 'Length', 'Weight', 'Horsepower'],
#  ['Make', 'Type', 'Wheelbase', 'Origin', 'Weight', 'Horsepower', 'Length'],
#  ['Make', 'Type', 'Wheelbase', 'Origin', 'Weight', 'Length', 'Horsepower'],
#  ['Make', 'Type', 'Wheelbase', 'Horsepower', 'Origin', 'Length', 'Weight'],
#  ['Make', 'Type', 'Wheelbase', 'Horsepower', 'Origin', 'Weight', 'Length'],
#  ['Make', 'Type', 'Wheelbase', 'Horsepower', 'Length', 'Origin', 'Weight'],
#  ['Make', 'Type', 'Wheelbase', 'Horsepower', 'Length', 'Weight', 'Origin'],
#  ['Make', 'Type', 'Wheelbase', 'Horsepower', 'Weight', 'Origin', 'Length'],
#  ['Make', 'Type', 'Wheelbase', 'Horsepower', 'Weight', 'Length', 'Origin'],
#  ['Make', 'Type', 'Wheelbase', 'Length', 'Origin', 'Horsepower', 'Weight'],
#  ['Make', 'Type', 'Wheelbase', 'Length', 'Origin', 'Weight', 'Horsepower'],
#  ['Make', 'Type', 'Wheelbase', 'Length', 'Horsepower', 'Origin', 'Weight'],
#  ['Make', 'Type', 'Wheelbase', 'Length', 'Horsepower', 'Weight', 'Origin'],
#  ['Make', 'Type', 'Wheelbase', 'Length', 'Weight', 'Origin', 'Horsepower'],
#  ['Make', 'Type', 'Wheelbase', 'Length', 'Weight', 'Horsepower', 'Origin'],
#  ['Make', 'Type', 'Wheelbase', 'Weight', 'Origin', 'Horsepower', 'Length'],
#  ['Make', 'Type', 'Wheelbase', 'Weight', 'Origin', 'Length', 'Horsepower'],
#  ['Make', 'Type', 'Wheelbase', 'Weight', 'Horsepower', 'Origin', 'Length'],
#  ['Make', 'Type', 'Wheelbase', 'Weight', 'Horsepower', 'Length', 'Origin'],
#  ['Make', 'Type', 'Wheelbase', 'Weight', 'Length', 'Origin', 'Horsepower'],
#  ['Make', 'Type', 'Wheelbase', 'Weight', 'Length', 'Horsepower', 'Origin'],
#  ['Make', 'Horsepower', 'Origin', 'Type', 'Length', 'Weight', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Origin', 'Type', 'Length', 'Wheelbase', 'Weight'],
#  ['Make', 'Horsepower', 'Origin', 'Type', 'Weight', 'Length', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Origin', 'Type', 'Weight', 'Wheelbase', 'Length'],
#  ['Make', 'Horsepower', 'Origin', 'Type', 'Wheelbase', 'Length', 'Weight'],
#  ['Make', 'Horsepower', 'Origin', 'Type', 'Wheelbase', 'Weight', 'Length'],
#  ['Make', 'Horsepower', 'Origin', 'Length', 'Type', 'Weight', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Origin', 'Length', 'Type', 'Wheelbase', 'Weight'],
#  ['Make', 'Horsepower', 'Origin', 'Length', 'Weight', 'Type', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Origin', 'Length', 'Weight', 'Wheelbase', 'Type'],
#  ['Make', 'Horsepower', 'Origin', 'Length', 'Wheelbase', 'Type', 'Weight'],
#  ['Make', 'Horsepower', 'Origin', 'Length', 'Wheelbase', 'Weight', 'Type'],
#  ['Make', 'Horsepower', 'Origin', 'Weight', 'Type', 'Length', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Origin', 'Weight', 'Type', 'Wheelbase', 'Length'],
#  ['Make', 'Horsepower', 'Origin', 'Weight', 'Length', 'Type', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Origin', 'Weight', 'Length', 'Wheelbase', 'Type'],
#  ['Make', 'Horsepower', 'Origin', 'Weight', 'Wheelbase', 'Type', 'Length'],
#  ['Make', 'Horsepower', 'Origin', 'Weight', 'Wheelbase', 'Length', 'Type'],
#  ['Make', 'Horsepower', 'Origin', 'Wheelbase', 'Type', 'Length', 'Weight'],
#  ['Make', 'Horsepower', 'Origin', 'Wheelbase', 'Type', 'Weight', 'Length'],
#  ['Make', 'Horsepower', 'Origin', 'Wheelbase', 'Length', 'Type', 'Weight'],
#  ['Make', 'Horsepower', 'Origin', 'Wheelbase', 'Length', 'Weight', 'Type'],
#  ['Make', 'Horsepower', 'Origin', 'Wheelbase', 'Weight', 'Type', 'Length'],
#  ['Make', 'Horsepower', 'Origin', 'Wheelbase', 'Weight', 'Length', 'Type'],
#  ['Make', 'Horsepower', 'Type', 'Origin', 'Length', 'Weight', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Type', 'Origin', 'Length', 'Wheelbase', 'Weight'],
#  ['Make', 'Horsepower', 'Type', 'Origin', 'Weight', 'Length', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Type', 'Origin', 'Weight', 'Wheelbase', 'Length'],
#  ['Make', 'Horsepower', 'Type', 'Origin', 'Wheelbase', 'Length', 'Weight'],
#  ['Make', 'Horsepower', 'Type', 'Origin', 'Wheelbase', 'Weight', 'Length'],
#  ['Make', 'Horsepower', 'Type', 'Length', 'Origin', 'Weight', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Type', 'Length', 'Origin', 'Wheelbase', 'Weight'],
#  ['Make', 'Horsepower', 'Type', 'Length', 'Weight', 'Origin', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Type', 'Length', 'Weight', 'Wheelbase', 'Origin'],
#  ['Make', 'Horsepower', 'Type', 'Length', 'Wheelbase', 'Origin', 'Weight'],
#  ['Make', 'Horsepower', 'Type', 'Length', 'Wheelbase', 'Weight', 'Origin'],
#  ['Make', 'Horsepower', 'Type', 'Weight', 'Origin', 'Length', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Type', 'Weight', 'Origin', 'Wheelbase', 'Length'],
#  ['Make', 'Horsepower', 'Type', 'Weight', 'Length', 'Origin', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Type', 'Weight', 'Length', 'Wheelbase', 'Origin'],
#  ['Make', 'Horsepower', 'Type', 'Weight', 'Wheelbase', 'Origin', 'Length'],
#  ['Make', 'Horsepower', 'Type', 'Weight', 'Wheelbase', 'Length', 'Origin'],
#  ['Make', 'Horsepower', 'Type', 'Wheelbase', 'Origin', 'Length', 'Weight'],
#  ['Make', 'Horsepower', 'Type', 'Wheelbase', 'Origin', 'Weight', 'Length'],
#  ['Make', 'Horsepower', 'Type', 'Wheelbase', 'Length', 'Origin', 'Weight'],
#  ['Make', 'Horsepower', 'Type', 'Wheelbase', 'Length', 'Weight', 'Origin'],
#  ['Make', 'Horsepower', 'Type', 'Wheelbase', 'Weight', 'Origin', 'Length'],
#  ['Make', 'Horsepower', 'Type', 'Wheelbase', 'Weight', 'Length', 'Origin'],
#  ['Make', 'Horsepower', 'Length', 'Origin', 'Type', 'Weight', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Length', 'Origin', 'Type', 'Wheelbase', 'Weight'],
#  ['Make', 'Horsepower', 'Length', 'Origin', 'Weight', 'Type', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Length', 'Origin', 'Weight', 'Wheelbase', 'Type'],
#  ['Make', 'Horsepower', 'Length', 'Origin', 'Wheelbase', 'Type', 'Weight'],
#  ['Make', 'Horsepower', 'Length', 'Origin', 'Wheelbase', 'Weight', 'Type'],
#  ['Make', 'Horsepower', 'Length', 'Type', 'Origin', 'Weight', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Length', 'Type', 'Origin', 'Wheelbase', 'Weight'],
#  ['Make', 'Horsepower', 'Length', 'Type', 'Weight', 'Origin', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Length', 'Type', 'Weight', 'Wheelbase', 'Origin'],
#  ['Make', 'Horsepower', 'Length', 'Type', 'Wheelbase', 'Origin', 'Weight'],
#  ['Make', 'Horsepower', 'Length', 'Type', 'Wheelbase', 'Weight', 'Origin'],
#  ['Make', 'Horsepower', 'Length', 'Weight', 'Origin', 'Type', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Length', 'Weight', 'Origin', 'Wheelbase', 'Type'],
#  ['Make', 'Horsepower', 'Length', 'Weight', 'Type', 'Origin', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Length', 'Weight', 'Type', 'Wheelbase', 'Origin'],
#  ['Make', 'Horsepower', 'Length', 'Weight', 'Wheelbase', 'Origin', 'Type'],
#  ['Make', 'Horsepower', 'Length', 'Weight', 'Wheelbase', 'Type', 'Origin'],
#  ['Make', 'Horsepower', 'Length', 'Wheelbase', 'Origin', 'Type', 'Weight'],
#  ['Make', 'Horsepower', 'Length', 'Wheelbase', 'Origin', 'Weight', 'Type'],
#  ['Make', 'Horsepower', 'Length', 'Wheelbase', 'Type', 'Origin', 'Weight'],
#  ['Make', 'Horsepower', 'Length', 'Wheelbase', 'Type', 'Weight', 'Origin'],
#  ['Make', 'Horsepower', 'Length', 'Wheelbase', 'Weight', 'Origin', 'Type'],
#  ['Make', 'Horsepower', 'Length', 'Wheelbase', 'Weight', 'Type', 'Origin'],
#  ['Make', 'Horsepower', 'Weight', 'Origin', 'Type', 'Length', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Weight', 'Origin', 'Type', 'Wheelbase', 'Length'],
#  ['Make', 'Horsepower', 'Weight', 'Origin', 'Length', 'Type', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Weight', 'Origin', 'Length', 'Wheelbase', 'Type'],
#  ['Make', 'Horsepower', 'Weight', 'Origin', 'Wheelbase', 'Type', 'Length'],
#  ['Make', 'Horsepower', 'Weight', 'Origin', 'Wheelbase', 'Length', 'Type'],
#  ['Make', 'Horsepower', 'Weight', 'Type', 'Origin', 'Length', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Weight', 'Type', 'Origin', 'Wheelbase', 'Length'],
#  ['Make', 'Horsepower', 'Weight', 'Type', 'Length', 'Origin', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Weight', 'Type', 'Length', 'Wheelbase', 'Origin'],
#  ['Make', 'Horsepower', 'Weight', 'Type', 'Wheelbase', 'Origin', 'Length'],
#  ['Make', 'Horsepower', 'Weight', 'Type', 'Wheelbase', 'Length', 'Origin'],
#  ['Make', 'Horsepower', 'Weight', 'Length', 'Origin', 'Type', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Weight', 'Length', 'Origin', 'Wheelbase', 'Type'],
#  ['Make', 'Horsepower', 'Weight', 'Length', 'Type', 'Origin', 'Wheelbase'],
#  ['Make', 'Horsepower', 'Weight', 'Length', 'Type', 'Wheelbase', 'Origin'],
#  ['Make', 'Horsepower', 'Weight', 'Length', 'Wheelbase', 'Origin', 'Type'],
#  ['Make', 'Horsepower', 'Weight', 'Length', 'Wheelbase', 'Type', 'Origin'],
#  ['Make', 'Horsepower', 'Weight', 'Wheelbase', 'Origin', 'Type', 'Length'],
#  ['Make', 'Horsepower', 'Weight', 'Wheelbase', 'Origin', 'Length', 'Type'],
#  ['Make', 'Horsepower', 'Weight', 'Wheelbase', 'Type', 'Origin', 'Length'],
#  ['Make', 'Horsepower', 'Weight', 'Wheelbase', 'Type', 'Length', 'Origin'],
#  ['Make', 'Horsepower', 'Weight', 'Wheelbase', 'Length', 'Origin', 'Type'],
#  ['Make', 'Horsepower', 'Weight', 'Wheelbase', 'Length', 'Type', 'Origin'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Origin', 'Type', 'Length', 'Weight'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Origin', 'Type', 'Weight', 'Length'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Origin', 'Length', 'Type', 'Weight'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Origin', 'Length', 'Weight', 'Type'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Origin', 'Weight', 'Type', 'Length'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Origin', 'Weight', 'Length', 'Type'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Type', 'Origin', 'Length', 'Weight'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Type', 'Origin', 'Weight', 'Length'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Type', 'Length', 'Origin', 'Weight'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Type', 'Length', 'Weight', 'Origin'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Type', 'Weight', 'Origin', 'Length'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Type', 'Weight', 'Length', 'Origin'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Length', 'Origin', 'Type', 'Weight'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Length', 'Origin', 'Weight', 'Type'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Length', 'Type', 'Origin', 'Weight'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Length', 'Type', 'Weight', 'Origin'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Length', 'Weight', 'Origin', 'Type'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Length', 'Weight', 'Type', 'Origin'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Weight', 'Origin', 'Type', 'Length'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Weight', 'Origin', 'Length', 'Type'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Weight', 'Type', 'Origin', 'Length'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Weight', 'Type', 'Length', 'Origin'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Weight', 'Length', 'Origin', 'Type'],
#  ['Make', 'Horsepower', 'Wheelbase', 'Weight', 'Length', 'Type', 'Origin'],
#  ['Make', 'Length', 'Origin', 'Type', 'Horsepower', 'Weight', 'Wheelbase'],
#  ['Make', 'Length', 'Origin', 'Type', 'Horsepower', 'Wheelbase', 'Weight'],
#  ['Make', 'Length', 'Origin', 'Type', 'Weight', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Length', 'Origin', 'Type', 'Weight', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Length', 'Origin', 'Type', 'Wheelbase', 'Horsepower', 'Weight'],
#  ['Make', 'Length', 'Origin', 'Type', 'Wheelbase', 'Weight', 'Horsepower'],
#  ['Make', 'Length', 'Origin', 'Horsepower', 'Type', 'Weight', 'Wheelbase'],
#  ['Make', 'Length', 'Origin', 'Horsepower', 'Type', 'Wheelbase', 'Weight'],
#  ['Make', 'Length', 'Origin', 'Horsepower', 'Weight', 'Type', 'Wheelbase'],
#  ['Make', 'Length', 'Origin', 'Horsepower', 'Weight', 'Wheelbase', 'Type'],
#  ['Make', 'Length', 'Origin', 'Horsepower', 'Wheelbase', 'Type', 'Weight'],
#  ['Make', 'Length', 'Origin', 'Horsepower', 'Wheelbase', 'Weight', 'Type'],
#  ['Make', 'Length', 'Origin', 'Weight', 'Type', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Length', 'Origin', 'Weight', 'Type', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Length', 'Origin', 'Weight', 'Horsepower', 'Type', 'Wheelbase'],
#  ['Make', 'Length', 'Origin', 'Weight', 'Horsepower', 'Wheelbase', 'Type'],
#  ['Make', 'Length', 'Origin', 'Weight', 'Wheelbase', 'Type', 'Horsepower'],
#  ['Make', 'Length', 'Origin', 'Weight', 'Wheelbase', 'Horsepower', 'Type'],
#  ['Make', 'Length', 'Origin', 'Wheelbase', 'Type', 'Horsepower', 'Weight'],
#  ['Make', 'Length', 'Origin', 'Wheelbase', 'Type', 'Weight', 'Horsepower'],
#  ['Make', 'Length', 'Origin', 'Wheelbase', 'Horsepower', 'Type', 'Weight'],
#  ['Make', 'Length', 'Origin', 'Wheelbase', 'Horsepower', 'Weight', 'Type'],
#  ['Make', 'Length', 'Origin', 'Wheelbase', 'Weight', 'Type', 'Horsepower'],
#  ['Make', 'Length', 'Origin', 'Wheelbase', 'Weight', 'Horsepower', 'Type'],
#  ['Make', 'Length', 'Type', 'Origin', 'Horsepower', 'Weight', 'Wheelbase'],
#  ['Make', 'Length', 'Type', 'Origin', 'Horsepower', 'Wheelbase', 'Weight'],
#  ['Make', 'Length', 'Type', 'Origin', 'Weight', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Length', 'Type', 'Origin', 'Weight', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Length', 'Type', 'Origin', 'Wheelbase', 'Horsepower', 'Weight'],
#  ['Make', 'Length', 'Type', 'Origin', 'Wheelbase', 'Weight', 'Horsepower'],
#  ['Make', 'Length', 'Type', 'Horsepower', 'Origin', 'Weight', 'Wheelbase'],
#  ['Make', 'Length', 'Type', 'Horsepower', 'Origin', 'Wheelbase', 'Weight'],
#  ['Make', 'Length', 'Type', 'Horsepower', 'Weight', 'Origin', 'Wheelbase'],
#  ['Make', 'Length', 'Type', 'Horsepower', 'Weight', 'Wheelbase', 'Origin'],
#  ['Make', 'Length', 'Type', 'Horsepower', 'Wheelbase', 'Origin', 'Weight'],
#  ['Make', 'Length', 'Type', 'Horsepower', 'Wheelbase', 'Weight', 'Origin'],
#  ['Make', 'Length', 'Type', 'Weight', 'Origin', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Length', 'Type', 'Weight', 'Origin', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Length', 'Type', 'Weight', 'Horsepower', 'Origin', 'Wheelbase'],
#  ['Make', 'Length', 'Type', 'Weight', 'Horsepower', 'Wheelbase', 'Origin'],
#  ['Make', 'Length', 'Type', 'Weight', 'Wheelbase', 'Origin', 'Horsepower'],
#  ['Make', 'Length', 'Type', 'Weight', 'Wheelbase', 'Horsepower', 'Origin'],
#  ['Make', 'Length', 'Type', 'Wheelbase', 'Origin', 'Horsepower', 'Weight'],
#  ['Make', 'Length', 'Type', 'Wheelbase', 'Origin', 'Weight', 'Horsepower'],
#  ['Make', 'Length', 'Type', 'Wheelbase', 'Horsepower', 'Origin', 'Weight'],
#  ['Make', 'Length', 'Type', 'Wheelbase', 'Horsepower', 'Weight', 'Origin'],
#  ['Make', 'Length', 'Type', 'Wheelbase', 'Weight', 'Origin', 'Horsepower'],
#  ['Make', 'Length', 'Type', 'Wheelbase', 'Weight', 'Horsepower', 'Origin'],
#  ['Make', 'Length', 'Horsepower', 'Origin', 'Type', 'Weight', 'Wheelbase'],
#  ['Make', 'Length', 'Horsepower', 'Origin', 'Type', 'Wheelbase', 'Weight'],
#  ['Make', 'Length', 'Horsepower', 'Origin', 'Weight', 'Type', 'Wheelbase'],
#  ['Make', 'Length', 'Horsepower', 'Origin', 'Weight', 'Wheelbase', 'Type'],
#  ['Make', 'Length', 'Horsepower', 'Origin', 'Wheelbase', 'Type', 'Weight'],
#  ['Make', 'Length', 'Horsepower', 'Origin', 'Wheelbase', 'Weight', 'Type'],
#  ['Make', 'Length', 'Horsepower', 'Type', 'Origin', 'Weight', 'Wheelbase'],
#  ['Make', 'Length', 'Horsepower', 'Type', 'Origin', 'Wheelbase', 'Weight'],
#  ['Make', 'Length', 'Horsepower', 'Type', 'Weight', 'Origin', 'Wheelbase'],
#  ['Make', 'Length', 'Horsepower', 'Type', 'Weight', 'Wheelbase', 'Origin'],
#  ['Make', 'Length', 'Horsepower', 'Type', 'Wheelbase', 'Origin', 'Weight'],
#  ['Make', 'Length', 'Horsepower', 'Type', 'Wheelbase', 'Weight', 'Origin'],
#  ['Make', 'Length', 'Horsepower', 'Weight', 'Origin', 'Type', 'Wheelbase'],
#  ['Make', 'Length', 'Horsepower', 'Weight', 'Origin', 'Wheelbase', 'Type'],
#  ['Make', 'Length', 'Horsepower', 'Weight', 'Type', 'Origin', 'Wheelbase'],
#  ['Make', 'Length', 'Horsepower', 'Weight', 'Type', 'Wheelbase', 'Origin'],
#  ['Make', 'Length', 'Horsepower', 'Weight', 'Wheelbase', 'Origin', 'Type'],
#  ['Make', 'Length', 'Horsepower', 'Weight', 'Wheelbase', 'Type', 'Origin'],
#  ['Make', 'Length', 'Horsepower', 'Wheelbase', 'Origin', 'Type', 'Weight'],
#  ['Make', 'Length', 'Horsepower', 'Wheelbase', 'Origin', 'Weight', 'Type'],
#  ['Make', 'Length', 'Horsepower', 'Wheelbase', 'Type', 'Origin', 'Weight'],
#  ['Make', 'Length', 'Horsepower', 'Wheelbase', 'Type', 'Weight', 'Origin'],
#  ['Make', 'Length', 'Horsepower', 'Wheelbase', 'Weight', 'Origin', 'Type'],
#  ['Make', 'Length', 'Horsepower', 'Wheelbase', 'Weight', 'Type', 'Origin'],
#  ['Make', 'Length', 'Weight', 'Origin', 'Type', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Length', 'Weight', 'Origin', 'Type', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Length', 'Weight', 'Origin', 'Horsepower', 'Type', 'Wheelbase'],
#  ['Make', 'Length', 'Weight', 'Origin', 'Horsepower', 'Wheelbase', 'Type'],
#  ['Make', 'Length', 'Weight', 'Origin', 'Wheelbase', 'Type', 'Horsepower'],
#  ['Make', 'Length', 'Weight', 'Origin', 'Wheelbase', 'Horsepower', 'Type'],
#  ['Make', 'Length', 'Weight', 'Type', 'Origin', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Length', 'Weight', 'Type', 'Origin', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Length', 'Weight', 'Type', 'Horsepower', 'Origin', 'Wheelbase'],
#  ['Make', 'Length', 'Weight', 'Type', 'Horsepower', 'Wheelbase', 'Origin'],
#  ['Make', 'Length', 'Weight', 'Type', 'Wheelbase', 'Origin', 'Horsepower'],
#  ['Make', 'Length', 'Weight', 'Type', 'Wheelbase', 'Horsepower', 'Origin'],
#  ['Make', 'Length', 'Weight', 'Horsepower', 'Origin', 'Type', 'Wheelbase'],
#  ['Make', 'Length', 'Weight', 'Horsepower', 'Origin', 'Wheelbase', 'Type'],
#  ['Make', 'Length', 'Weight', 'Horsepower', 'Type', 'Origin', 'Wheelbase'],
#  ['Make', 'Length', 'Weight', 'Horsepower', 'Type', 'Wheelbase', 'Origin'],
#  ['Make', 'Length', 'Weight', 'Horsepower', 'Wheelbase', 'Origin', 'Type'],
#  ['Make', 'Length', 'Weight', 'Horsepower', 'Wheelbase', 'Type', 'Origin'],
#  ['Make', 'Length', 'Weight', 'Wheelbase', 'Origin', 'Type', 'Horsepower'],
#  ['Make', 'Length', 'Weight', 'Wheelbase', 'Origin', 'Horsepower', 'Type'],
#  ['Make', 'Length', 'Weight', 'Wheelbase', 'Type', 'Origin', 'Horsepower'],
#  ['Make', 'Length', 'Weight', 'Wheelbase', 'Type', 'Horsepower', 'Origin'],
#  ['Make', 'Length', 'Weight', 'Wheelbase', 'Horsepower', 'Origin', 'Type'],
#  ['Make', 'Length', 'Weight', 'Wheelbase', 'Horsepower', 'Type', 'Origin'],
#  ['Make', 'Length', 'Wheelbase', 'Origin', 'Type', 'Horsepower', 'Weight'],
#  ['Make', 'Length', 'Wheelbase', 'Origin', 'Type', 'Weight', 'Horsepower'],
#  ['Make', 'Length', 'Wheelbase', 'Origin', 'Horsepower', 'Type', 'Weight'],
#  ['Make', 'Length', 'Wheelbase', 'Origin', 'Horsepower', 'Weight', 'Type'],
#  ['Make', 'Length', 'Wheelbase', 'Origin', 'Weight', 'Type', 'Horsepower'],
#  ['Make', 'Length', 'Wheelbase', 'Origin', 'Weight', 'Horsepower', 'Type'],
#  ['Make', 'Length', 'Wheelbase', 'Type', 'Origin', 'Horsepower', 'Weight'],
#  ['Make', 'Length', 'Wheelbase', 'Type', 'Origin', 'Weight', 'Horsepower'],
#  ['Make', 'Length', 'Wheelbase', 'Type', 'Horsepower', 'Origin', 'Weight'],
#  ['Make', 'Length', 'Wheelbase', 'Type', 'Horsepower', 'Weight', 'Origin'],
#  ['Make', 'Length', 'Wheelbase', 'Type', 'Weight', 'Origin', 'Horsepower'],
#  ['Make', 'Length', 'Wheelbase', 'Type', 'Weight', 'Horsepower', 'Origin'],
#  ['Make', 'Length', 'Wheelbase', 'Horsepower', 'Origin', 'Type', 'Weight'],
#  ['Make', 'Length', 'Wheelbase', 'Horsepower', 'Origin', 'Weight', 'Type'],
#  ['Make', 'Length', 'Wheelbase', 'Horsepower', 'Type', 'Origin', 'Weight'],
#  ['Make', 'Length', 'Wheelbase', 'Horsepower', 'Type', 'Weight', 'Origin'],
#  ['Make', 'Length', 'Wheelbase', 'Horsepower', 'Weight', 'Origin', 'Type'],
#  ['Make', 'Length', 'Wheelbase', 'Horsepower', 'Weight', 'Type', 'Origin'],
#  ['Make', 'Length', 'Wheelbase', 'Weight', 'Origin', 'Type', 'Horsepower'],
#  ['Make', 'Length', 'Wheelbase', 'Weight', 'Origin', 'Horsepower', 'Type'],
#  ['Make', 'Length', 'Wheelbase', 'Weight', 'Type', 'Origin', 'Horsepower'],
#  ['Make', 'Length', 'Wheelbase', 'Weight', 'Type', 'Horsepower', 'Origin'],
#  ['Make', 'Length', 'Wheelbase', 'Weight', 'Horsepower', 'Origin', 'Type'],
#  ['Make', 'Length', 'Wheelbase', 'Weight', 'Horsepower', 'Type', 'Origin'],
#  ['Make', 'Weight', 'Origin', 'Type', 'Horsepower', 'Length', 'Wheelbase'],
#  ['Make', 'Weight', 'Origin', 'Type', 'Horsepower', 'Wheelbase', 'Length'],
#  ['Make', 'Weight', 'Origin', 'Type', 'Length', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Weight', 'Origin', 'Type', 'Length', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Weight', 'Origin', 'Type', 'Wheelbase', 'Horsepower', 'Length'],
#  ['Make', 'Weight', 'Origin', 'Type', 'Wheelbase', 'Length', 'Horsepower'],
#  ['Make', 'Weight', 'Origin', 'Horsepower', 'Type', 'Length', 'Wheelbase'],
#  ['Make', 'Weight', 'Origin', 'Horsepower', 'Type', 'Wheelbase', 'Length'],
#  ['Make', 'Weight', 'Origin', 'Horsepower', 'Length', 'Type', 'Wheelbase'],
#  ['Make', 'Weight', 'Origin', 'Horsepower', 'Length', 'Wheelbase', 'Type'],
#  ['Make', 'Weight', 'Origin', 'Horsepower', 'Wheelbase', 'Type', 'Length'],
#  ['Make', 'Weight', 'Origin', 'Horsepower', 'Wheelbase', 'Length', 'Type'],
#  ['Make', 'Weight', 'Origin', 'Length', 'Type', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Weight', 'Origin', 'Length', 'Type', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Weight', 'Origin', 'Length', 'Horsepower', 'Type', 'Wheelbase'],
#  ['Make', 'Weight', 'Origin', 'Length', 'Horsepower', 'Wheelbase', 'Type'],
#  ['Make', 'Weight', 'Origin', 'Length', 'Wheelbase', 'Type', 'Horsepower'],
#  ['Make', 'Weight', 'Origin', 'Length', 'Wheelbase', 'Horsepower', 'Type'],
#  ['Make', 'Weight', 'Origin', 'Wheelbase', 'Type', 'Horsepower', 'Length'],
#  ['Make', 'Weight', 'Origin', 'Wheelbase', 'Type', 'Length', 'Horsepower'],
#  ['Make', 'Weight', 'Origin', 'Wheelbase', 'Horsepower', 'Type', 'Length'],
#  ['Make', 'Weight', 'Origin', 'Wheelbase', 'Horsepower', 'Length', 'Type'],
#  ['Make', 'Weight', 'Origin', 'Wheelbase', 'Length', 'Type', 'Horsepower'],
#  ['Make', 'Weight', 'Origin', 'Wheelbase', 'Length', 'Horsepower', 'Type'],
#  ['Make', 'Weight', 'Type', 'Origin', 'Horsepower', 'Length', 'Wheelbase'],
#  ['Make', 'Weight', 'Type', 'Origin', 'Horsepower', 'Wheelbase', 'Length'],
#  ['Make', 'Weight', 'Type', 'Origin', 'Length', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Weight', 'Type', 'Origin', 'Length', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Weight', 'Type', 'Origin', 'Wheelbase', 'Horsepower', 'Length'],
#  ['Make', 'Weight', 'Type', 'Origin', 'Wheelbase', 'Length', 'Horsepower'],
#  ['Make', 'Weight', 'Type', 'Horsepower', 'Origin', 'Length', 'Wheelbase'],
#  ['Make', 'Weight', 'Type', 'Horsepower', 'Origin', 'Wheelbase', 'Length'],
#  ['Make', 'Weight', 'Type', 'Horsepower', 'Length', 'Origin', 'Wheelbase'],
#  ['Make', 'Weight', 'Type', 'Horsepower', 'Length', 'Wheelbase', 'Origin'],
#  ['Make', 'Weight', 'Type', 'Horsepower', 'Wheelbase', 'Origin', 'Length'],
#  ['Make', 'Weight', 'Type', 'Horsepower', 'Wheelbase', 'Length', 'Origin'],
#  ['Make', 'Weight', 'Type', 'Length', 'Origin', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Weight', 'Type', 'Length', 'Origin', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Weight', 'Type', 'Length', 'Horsepower', 'Origin', 'Wheelbase'],
#  ['Make', 'Weight', 'Type', 'Length', 'Horsepower', 'Wheelbase', 'Origin'],
#  ['Make', 'Weight', 'Type', 'Length', 'Wheelbase', 'Origin', 'Horsepower'],
#  ['Make', 'Weight', 'Type', 'Length', 'Wheelbase', 'Horsepower', 'Origin'],
#  ['Make', 'Weight', 'Type', 'Wheelbase', 'Origin', 'Horsepower', 'Length'],
#  ['Make', 'Weight', 'Type', 'Wheelbase', 'Origin', 'Length', 'Horsepower'],
#  ['Make', 'Weight', 'Type', 'Wheelbase', 'Horsepower', 'Origin', 'Length'],
#  ['Make', 'Weight', 'Type', 'Wheelbase', 'Horsepower', 'Length', 'Origin'],
#  ['Make', 'Weight', 'Type', 'Wheelbase', 'Length', 'Origin', 'Horsepower'],
#  ['Make', 'Weight', 'Type', 'Wheelbase', 'Length', 'Horsepower', 'Origin'],
#  ['Make', 'Weight', 'Horsepower', 'Origin', 'Type', 'Length', 'Wheelbase'],
#  ['Make', 'Weight', 'Horsepower', 'Origin', 'Type', 'Wheelbase', 'Length'],
#  ['Make', 'Weight', 'Horsepower', 'Origin', 'Length', 'Type', 'Wheelbase'],
#  ['Make', 'Weight', 'Horsepower', 'Origin', 'Length', 'Wheelbase', 'Type'],
#  ['Make', 'Weight', 'Horsepower', 'Origin', 'Wheelbase', 'Type', 'Length'],
#  ['Make', 'Weight', 'Horsepower', 'Origin', 'Wheelbase', 'Length', 'Type'],
#  ['Make', 'Weight', 'Horsepower', 'Type', 'Origin', 'Length', 'Wheelbase'],
#  ['Make', 'Weight', 'Horsepower', 'Type', 'Origin', 'Wheelbase', 'Length'],
#  ['Make', 'Weight', 'Horsepower', 'Type', 'Length', 'Origin', 'Wheelbase'],
#  ['Make', 'Weight', 'Horsepower', 'Type', 'Length', 'Wheelbase', 'Origin'],
#  ['Make', 'Weight', 'Horsepower', 'Type', 'Wheelbase', 'Origin', 'Length'],
#  ['Make', 'Weight', 'Horsepower', 'Type', 'Wheelbase', 'Length', 'Origin'],
#  ['Make', 'Weight', 'Horsepower', 'Length', 'Origin', 'Type', 'Wheelbase'],
#  ['Make', 'Weight', 'Horsepower', 'Length', 'Origin', 'Wheelbase', 'Type'],
#  ['Make', 'Weight', 'Horsepower', 'Length', 'Type', 'Origin', 'Wheelbase'],
#  ['Make', 'Weight', 'Horsepower', 'Length', 'Type', 'Wheelbase', 'Origin'],
#  ['Make', 'Weight', 'Horsepower', 'Length', 'Wheelbase', 'Origin', 'Type'],
#  ['Make', 'Weight', 'Horsepower', 'Length', 'Wheelbase', 'Type', 'Origin'],
#  ['Make', 'Weight', 'Horsepower', 'Wheelbase', 'Origin', 'Type', 'Length'],
#  ['Make', 'Weight', 'Horsepower', 'Wheelbase', 'Origin', 'Length', 'Type'],
#  ['Make', 'Weight', 'Horsepower', 'Wheelbase', 'Type', 'Origin', 'Length'],
#  ['Make', 'Weight', 'Horsepower', 'Wheelbase', 'Type', 'Length', 'Origin'],
#  ['Make', 'Weight', 'Horsepower', 'Wheelbase', 'Length', 'Origin', 'Type'],
#  ['Make', 'Weight', 'Horsepower', 'Wheelbase', 'Length', 'Type', 'Origin'],
#  ['Make', 'Weight', 'Length', 'Origin', 'Type', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Weight', 'Length', 'Origin', 'Type', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Weight', 'Length', 'Origin', 'Horsepower', 'Type', 'Wheelbase'],
#  ['Make', 'Weight', 'Length', 'Origin', 'Horsepower', 'Wheelbase', 'Type'],
#  ['Make', 'Weight', 'Length', 'Origin', 'Wheelbase', 'Type', 'Horsepower'],
#  ['Make', 'Weight', 'Length', 'Origin', 'Wheelbase', 'Horsepower', 'Type'],
#  ['Make', 'Weight', 'Length', 'Type', 'Origin', 'Horsepower', 'Wheelbase'],
#  ['Make', 'Weight', 'Length', 'Type', 'Origin', 'Wheelbase', 'Horsepower'],
#  ['Make', 'Weight', 'Length', 'Type', 'Horsepower', 'Origin', 'Wheelbase'],
#  ['Make', 'Weight', 'Length', 'Type', 'Horsepower', 'Wheelbase', 'Origin'],
#  ['Make', 'Weight', 'Length', 'Type', 'Wheelbase', 'Origin', 'Horsepower'],
#  ['Make', 'Weight', 'Length', 'Type', 'Wheelbase', 'Horsepower', 'Origin'],
#  ['Make', 'Weight', 'Length', 'Horsepower', 'Origin', 'Type', 'Wheelbase'],
#  ['Make', 'Weight', 'Length', 'Horsepower', 'Origin', 'Wheelbase', 'Type'],
#  ['Make', 'Weight', 'Length', 'Horsepower', 'Type', 'Origin', 'Wheelbase'],
#  ['Make', 'Weight', 'Length', 'Horsepower', 'Type', 'Wheelbase', 'Origin'],
#  ['Make', 'Weight', 'Length', 'Horsepower', 'Wheelbase', 'Origin', 'Type'],
#  ['Make', 'Weight', 'Length', 'Horsepower', 'Wheelbase', 'Type', 'Origin'],
#  ['Make', 'Weight', 'Length', 'Wheelbase', 'Origin', 'Type', 'Horsepower'],
#  ['Make', 'Weight', 'Length', 'Wheelbase', 'Origin', 'Horsepower', 'Type'],
#  ['Make', 'Weight', 'Length', 'Wheelbase', 'Type', 'Origin', 'Horsepower'],
#  ['Make', 'Weight', 'Length', 'Wheelbase', 'Type', 'Horsepower', 'Origin'],
#  ['Make', 'Weight', 'Length', 'Wheelbase', 'Horsepower', 'Origin', 'Type'],
#  ['Make', 'Weight', 'Length', 'Wheelbase', 'Horsepower', 'Type', 'Origin'],
#  ['Make', 'Weight', 'Wheelbase', 'Origin', 'Type', 'Horsepower', 'Length'],
#  ['Make', 'Weight', 'Wheelbase', 'Origin', 'Type', 'Length', 'Horsepower'],
#  ['Make', 'Weight', 'Wheelbase', 'Origin', 'Horsepower', 'Type', 'Length'],
#  ['Make', 'Weight', 'Wheelbase', 'Origin', 'Horsepower', 'Length', 'Type'],
#  ['Make', 'Weight', 'Wheelbase', 'Origin', 'Length', 'Type', 'Horsepower'],
#  ['Make', 'Weight', 'Wheelbase', 'Origin', 'Length', 'Horsepower', 'Type'],
#  ['Make', 'Weight', 'Wheelbase', 'Type', 'Origin', 'Horsepower', 'Length'],
#  ['Make', 'Weight', 'Wheelbase', 'Type', 'Origin', 'Length', 'Horsepower'],
#  ['Make', 'Weight', 'Wheelbase', 'Type', 'Horsepower', 'Origin', 'Length'],
#  ['Make', 'Weight', 'Wheelbase', 'Type', 'Horsepower', 'Length', 'Origin'],
#  ['Make', 'Weight', 'Wheelbase', 'Type', 'Length', 'Origin', 'Horsepower'],
#  ['Make', 'Weight', 'Wheelbase', 'Type', 'Length', 'Horsepower', 'Origin'],
#  ['Make', 'Weight', 'Wheelbase', 'Horsepower', 'Origin', 'Type', 'Length'],
#  ['Make', 'Weight', 'Wheelbase', 'Horsepower', 'Origin', 'Length', 'Type'],
#  ['Make', 'Weight', 'Wheelbase', 'Horsepower', 'Type', 'Origin', 'Length'],
#  ['Make', 'Weight', 'Wheelbase', 'Horsepower', 'Type', 'Length', 'Origin'],
#  ['Make', 'Weight', 'Wheelbase', 'Horsepower', 'Length', 'Origin', 'Type'],
#  ['Make', 'Weight', 'Wheelbase', 'Horsepower', 'Length', 'Type', 'Origin'],
#  ['Make', 'Weight', 'Wheelbase', 'Length', 'Origin', 'Type', 'Horsepower'],
#  ['Make', 'Weight', 'Wheelbase', 'Length', 'Origin', 'Horsepower', 'Type'],
#  ['Make', 'Weight', 'Wheelbase', 'Length', 'Type', 'Origin', 'Horsepower'],
#  ['Make', 'Weight', 'Wheelbase', 'Length', 'Type', 'Horsepower', 'Origin'],
#  ['Make', 'Weight', 'Wheelbase', 'Length', 'Horsepower', 'Origin', 'Type'],
#  ['Make', 'Weight', 'Wheelbase', 'Length', 'Horsepower', 'Type', 'Origin'],
#  ['Make', 'Wheelbase', 'Origin', 'Type', 'Horsepower', 'Length', 'Weight'],
#  ['Make', 'Wheelbase', 'Origin', 'Type', 'Horsepower', 'Weight', 'Length'],
#  ['Make', 'Wheelbase', 'Origin', 'Type', 'Length', 'Horsepower', 'Weight'],
#  ['Make', 'Wheelbase', 'Origin', 'Type', 'Length', 'Weight', 'Horsepower'],
#  ['Make', 'Wheelbase', 'Origin', 'Type', 'Weight', 'Horsepower', 'Length'],
#  ['Make', 'Wheelbase', 'Origin', 'Type', 'Weight', 'Length', 'Horsepower'],
#  ['Make', 'Wheelbase', 'Origin', 'Horsepower', 'Type', 'Length', 'Weight'],
#  ['Make', 'Wheelbase', 'Origin', 'Horsepower', 'Type', 'Weight', 'Length'],
#  ['Make', 'Wheelbase', 'Origin', 'Horsepower', 'Length', 'Type', 'Weight'],
#  ['Make', 'Wheelbase', 'Origin', 'Horsepower', 'Length', 'Weight', 'Type'],
#  ['Make', 'Wheelbase', 'Origin', 'Horsepower', 'Weight', 'Type', 'Length'],
#  ['Make', 'Wheelbase', 'Origin', 'Horsepower', 'Weight', 'Length', 'Type'],
#  ['Make', 'Wheelbase', 'Origin', 'Length', 'Type', 'Horsepower', 'Weight'],
#  ['Make', 'Wheelbase', 'Origin', 'Length', 'Type', 'Weight', 'Horsepower'],
#  ['Make', 'Wheelbase', 'Origin', 'Length', 'Horsepower', 'Type', 'Weight'],
#  ['Make', 'Wheelbase', 'Origin', 'Length', 'Horsepower', 'Weight', 'Type'],
#  ['Make', 'Wheelbase', 'Origin', 'Length', 'Weight', 'Type', 'Horsepower'],
#  ['Make', 'Wheelbase', 'Origin', 'Length', 'Weight', 'Horsepower', 'Type'],
#  ['Make', 'Wheelbase', 'Origin', 'Weight', 'Type', 'Horsepower', 'Length'],
#  ['Make', 'Wheelbase', 'Origin', 'Weight', 'Type', 'Length', 'Horsepower'],
#  ['Make', 'Wheelbase', 'Origin', 'Weight', 'Horsepower', 'Type', 'Length'],
#  ['Make', 'Wheelbase', 'Origin', 'Weight', 'Horsepower', 'Length', 'Type'],
#  ['Make', 'Wheelbase', 'Origin', 'Weight', 'Length', 'Type', 'Horsepower'],
#  ['Make', 'Wheelbase', 'Origin', 'Weight', 'Length', 'Horsepower', 'Type'],
#  ['Make', 'Wheelbase', 'Type', 'Origin', 'Horsepower', 'Length', 'Weight'],
#  ['Make', 'Wheelbase', 'Type', 'Origin', 'Horsepower', 'Weight', 'Length'],
#  ['Make', 'Wheelbase', 'Type', 'Origin', 'Length', 'Horsepower', 'Weight'],
#  ['Make', 'Wheelbase', 'Type', 'Origin', 'Length', 'Weight', 'Horsepower'],
#  ['Make', 'Wheelbase', 'Type', 'Origin', 'Weight', 'Horsepower', 'Length'],
#  ['Make', 'Wheelbase', 'Type', 'Origin', 'Weight', 'Length', 'Horsepower'],
#  ['Make', 'Wheelbase', 'Type', 'Horsepower', 'Origin', 'Length', 'Weight'],
# ...
#  ['Origin', 'Make', 'Length', 'Wheelbase', 'Weight', 'Type', 'Horsepower'],
#  ['Origin', 'Make', 'Length', 'Wheelbase', 'Weight', 'Horsepower', 'Type'],
#  ['Origin', 'Make', 'Weight', 'Type', 'Horsepower', 'Length', 'Wheelbase'],
#  ['Origin', 'Make', 'Weight', 'Type', 'Horsepower', 'Wheelbase', 'Length'],
#  ['Origin', 'Make', 'Weight', 'Type', 'Length', 'Horsepower', 'Wheelbase'],
#  ['Origin', 'Make', 'Weight', 'Type', 'Length', 'Wheelbase', 'Horsepower'],
#  ['Origin', 'Make', 'Weight', 'Type', 'Wheelbase', 'Horsepower', 'Length'],
#  ['Origin', 'Make', 'Weight', 'Type', 'Wheelbase', 'Length', 'Horsepower'],
#  ['Origin', 'Make', 'Weight', 'Horsepower', 'Type', 'Length', 'Wheelbase'],
#  ['Origin', 'Make', 'Weight', 'Horsepower', 'Type', 'Wheelbase', 'Length'],
#  ['Origin', 'Make', 'Weight', 'Horsepower', 'Length', 'Type', 'Wheelbase'],
#  ['Origin', 'Make', 'Weight', 'Horsepower', 'Length', 'Wheelbase', 'Type'],
#  ['Origin', 'Make', 'Weight', 'Horsepower', 'Wheelbase', 'Type', 'Length'],
#  ['Origin', 'Make', 'Weight', 'Horsepower', 'Wheelbase', 'Length', 'Type'],
#  ['Origin', 'Make', 'Weight', 'Length', 'Type', 'Horsepower', 'Wheelbase'],
#  ['Origin', 'Make', 'Weight', 'Length', 'Type', 'Wheelbase', 'Horsepower'],
#  ['Origin', 'Make', 'Weight', 'Length', 'Horsepower', 'Type', 'Wheelbase'],
#  ['Origin', 'Make', 'Weight', 'Length', 'Horsepower', 'Wheelbase', 'Type'],
#  ['Origin', 'Make', 'Weight', 'Length', 'Wheelbase', 'Type', 'Horsepower'],
#  ['Origin', 'Make', 'Weight', 'Length', 'Wheelbase', 'Horsepower', 'Type'],
#  ['Origin', 'Make', 'Weight', 'Wheelbase', 'Type', 'Horsepower', 'Length'],
#  ['Origin', 'Make', 'Weight', 'Wheelbase', 'Type', 'Length', 'Horsepower'],
#  ['Origin', 'Make', 'Weight', 'Wheelbase', 'Horsepower', 'Type', 'Length'],
#  ['Origin', 'Make', 'Weight', 'Wheelbase', 'Horsepower', 'Length', 'Type'],
#  ['Origin', 'Make', 'Weight', 'Wheelbase', 'Length', 'Type', 'Horsepower'],
#  ['Origin', 'Make', 'Weight', 'Wheelbase', 'Length', 'Horsepower', 'Type'],
#  ['Origin', 'Make', 'Wheelbase', 'Type', 'Horsepower', 'Length', 'Weight'],
#  ['Origin', 'Make', 'Wheelbase', 'Type', 'Horsepower', 'Weight', 'Length'],
#  ['Origin', 'Make', 'Wheelbase', 'Type', 'Length', 'Horsepower', 'Weight'],
#  ['Origin', 'Make', 'Wheelbase', 'Type', 'Length', 'Weight', 'Horsepower'],
#  ['Origin', 'Make', 'Wheelbase', 'Type', 'Weight', 'Horsepower', 'Length'],
#  ['Origin', 'Make', 'Wheelbase', 'Type', 'Weight', 'Length', 'Horsepower'],
#  ['Origin', 'Make', 'Wheelbase', 'Horsepower', 'Type', 'Length', 'Weight'],
#  ['Origin', 'Make', 'Wheelbase', 'Horsepower', 'Type', 'Weight', 'Length'],
#  ['Origin', 'Make', 'Wheelbase', 'Horsepower', 'Length', 'Type', 'Weight'],
#  ['Origin', 'Make', 'Wheelbase', 'Horsepower', 'Length', 'Weight', 'Type'],
#  ['Origin', 'Make', 'Wheelbase', 'Horsepower', 'Weight', 'Type', 'Length'],
#  ['Origin', 'Make', 'Wheelbase', 'Horsepower', 'Weight', 'Length', 'Type'],
#  ['Origin', 'Make', 'Wheelbase', 'Length', 'Type', 'Horsepower', 'Weight'],
#  ['Origin', 'Make', 'Wheelbase', 'Length', 'Type', 'Weight', 'Horsepower'],
#  ['Origin', 'Make', 'Wheelbase', 'Length', 'Horsepower', 'Type', 'Weight'],
#  ['Origin', 'Make', 'Wheelbase', 'Length', 'Horsepower', 'Weight', 'Type'],
#  ['Origin', 'Make', 'Wheelbase', 'Length', 'Weight', 'Type', 'Horsepower'],
#  ['Origin', 'Make', 'Wheelbase', 'Length', 'Weight', 'Horsepower', 'Type'],
#  ['Origin', 'Make', 'Wheelbase', 'Weight', 'Type', 'Horsepower', 'Length'],
#  ['Origin', 'Make', 'Wheelbase', 'Weight', 'Type', 'Length', 'Horsepower'],
#  ['Origin', 'Make', 'Wheelbase', 'Weight', 'Horsepower', 'Type', 'Length'],
#  ['Origin', 'Make', 'Wheelbase', 'Weight', 'Horsepower', 'Length', 'Type'],
#  ['Origin', 'Make', 'Wheelbase', 'Weight', 'Length', 'Type', 'Horsepower'],
#  ['Origin', 'Make', 'Wheelbase', 'Weight', 'Length', 'Horsepower', 'Type'],
#  ['Origin', 'Type', 'Make', 'Horsepower', 'Length', 'Weight', 'Wheelbase'],
#  ['Origin', 'Type', 'Make', 'Horsepower', 'Length', 'Wheelbase', 'Weight'],
#  ['Origin', 'Type', 'Make', 'Horsepower', 'Weight', 'Length', 'Wheelbase'],
#  ['Origin', 'Type', 'Make', 'Horsepower', 'Weight', 'Wheelbase', 'Length'],
#  ['Origin', 'Type', 'Make', 'Horsepower', 'Wheelbase', 'Length', 'Weight'],
#  ['Origin', 'Type', 'Make', 'Horsepower', 'Wheelbase', 'Weight', 'Length'],
#  ['Origin', 'Type', 'Make', 'Length', 'Horsepower', 'Weight', 'Wheelbase'],
#  ['Origin', 'Type', 'Make', 'Length', 'Horsepower', 'Wheelbase', 'Weight'],
#  ['Origin', 'Type', 'Make', 'Length', 'Weight', 'Horsepower', 'Wheelbase'],
#  ['Origin', 'Type', 'Make', 'Length', 'Weight', 'Wheelbase', 'Horsepower'],
#  ['Origin', 'Type', 'Make', 'Length', 'Wheelbase', 'Horsepower', 'Weight'],
#  ['Origin', 'Type', 'Make', 'Length', 'Wheelbase', 'Weight', 'Horsepower'],
#  ['Origin', 'Type', 'Make', 'Weight', 'Horsepower', 'Length', 'Wheelbase'],
#  ['Origin', 'Type', 'Make', 'Weight', 'Horsepower', 'Wheelbase', 'Length'],
#  ['Origin', 'Type', 'Make', 'Weight', 'Length', 'Horsepower', 'Wheelbase'],
#  ['Origin', 'Type', 'Make', 'Weight', 'Length', 'Wheelbase', 'Horsepower'],
#  ['Origin', 'Type', 'Make', 'Weight', 'Wheelbase', 'Horsepower', 'Length'],
#  ['Origin', 'Type', 'Make', 'Weight', 'Wheelbase', 'Length', 'Horsepower'],
#  ['Origin', 'Type', 'Make', 'Wheelbase', 'Horsepower', 'Length', 'Weight'],
#  ['Origin', 'Type', 'Make', 'Wheelbase', 'Horsepower', 'Weight', 'Length'],
#  ['Origin', 'Type', 'Make', 'Wheelbase', 'Length', 'Horsepower', 'Weight'],
#  ['Origin', 'Type', 'Make', 'Wheelbase', 'Length', 'Weight', 'Horsepower'],
#  ['Origin', 'Type', 'Make', 'Wheelbase', 'Weight', 'Horsepower', 'Length'],
#  ['Origin', 'Type', 'Make', 'Wheelbase', 'Weight', 'Length', 'Horsepower'],
#  ['Origin', 'Type', 'Horsepower', 'Make', 'Length', 'Weight', 'Wheelbase'],
#  ['Origin', 'Type', 'Horsepower', 'Make', 'Length', 'Wheelbase', 'Weight'],
#  ['Origin', 'Type', 'Horsepower', 'Make', 'Weight', 'Length', 'Wheelbase'],
#  ['Origin', 'Type', 'Horsepower', 'Make', 'Weight', 'Wheelbase', 'Length'],
#  ['Origin', 'Type', 'Horsepower', 'Make', 'Wheelbase', 'Length', 'Weight'],
#  ['Origin', 'Type', 'Horsepower', 'Make', 'Wheelbase', 'Weight', 'Length'],
#  ['Origin', 'Type', 'Horsepower', 'Length', 'Make', 'Weight', 'Wheelbase'],
#  ['Origin', 'Type', 'Horsepower', 'Length', 'Make', 'Wheelbase', 'Weight'],
#  ['Origin', 'Type', 'Horsepower', 'Length', 'Weight', 'Make', 'Wheelbase'],
#  ['Origin', 'Type', 'Horsepower', 'Length', 'Weight', 'Wheelbase', 'Make'],
#  ['Origin', 'Type', 'Horsepower', 'Length', 'Wheelbase', 'Make', 'Weight'],
#  ['Origin', 'Type', 'Horsepower', 'Length', 'Wheelbase', 'Weight', 'Make'],
#  ['Origin', 'Type', 'Horsepower', 'Weight', 'Make', 'Length', 'Wheelbase'],
#  ['Origin', 'Type', 'Horsepower', 'Weight', 'Make', 'Wheelbase', 'Length'],
#  ['Origin', 'Type', 'Horsepower', 'Weight', 'Length', 'Make', 'Wheelbase'],
#  ['Origin', 'Type', 'Horsepower', 'Weight', 'Length', 'Wheelbase', 'Make'],
#  ['Origin', 'Type', 'Horsepower', 'Weight', 'Wheelbase', 'Make', 'Length'],
#  ['Origin', 'Type', 'Horsepower', 'Weight', 'Wheelbase', 'Length', 'Make'],
#  ['Origin', 'Type', 'Horsepower', 'Wheelbase', 'Make', 'Length', 'Weight'],
#  ['Origin', 'Type', 'Horsepower', 'Wheelbase', 'Make', 'Weight', 'Length'],
#  ['Origin', 'Type', 'Horsepower', 'Wheelbase', 'Length', 'Make', 'Weight'],
#  ['Origin', 'Type', 'Horsepower', 'Wheelbase', 'Length', 'Weight', 'Make'],
#  ['Origin', 'Type', 'Horsepower', 'Wheelbase', 'Weight', 'Make', 'Length'],
#  ['Origin', 'Type', 'Horsepower', 'Wheelbase', 'Weight', 'Length', 'Make'],
#  ['Origin', 'Type', 'Length', 'Make', 'Horsepower', 'Weight', 'Wheelbase'],
#  ['Origin', 'Type', 'Length', 'Make', 'Horsepower', 'Wheelbase', 'Weight'],
#  ['Origin', 'Type', 'Length', 'Make', 'Weight', 'Horsepower', 'Wheelbase'],
#  ['Origin', 'Type', 'Length', 'Make', 'Weight', 'Wheelbase', 'Horsepower'],
#  ['Origin', 'Type', 'Length', 'Make', 'Wheelbase', 'Horsepower', 'Weight'],
#  ['Origin', 'Type', 'Length', 'Make', 'Wheelbase', 'Weight', 'Horsepower'],
#  ['Origin', 'Type', 'Length', 'Horsepower', 'Make', 'Weight', 'Wheelbase'],
#  ['Origin', 'Type', 'Length', 'Horsepower', 'Make', 'Wheelbase', 'Weight'],
#  ['Origin', 'Type', 'Length', 'Horsepower', 'Weight', 'Make', 'Wheelbase'],
#  ['Origin', 'Type', 'Length', 'Horsepower', 'Weight', 'Wheelbase', 'Make'],
#  ['Origin', 'Type', 'Length', 'Horsepower', 'Wheelbase', 'Make', 'Weight'],
#  ['Origin', 'Type', 'Length', 'Horsepower', 'Wheelbase', 'Weight', 'Make'],
#  ['Origin', 'Type', 'Length', 'Weight', 'Make', 'Horsepower', 'Wheelbase'],
#  ['Origin', 'Type', 'Length', 'Weight', 'Make', 'Wheelbase', 'Horsepower'],
#  ['Origin', 'Type', 'Length', 'Weight', 'Horsepower', 'Make', 'Wheelbase'],
#  ['Origin', 'Type', 'Length', 'Weight', 'Horsepower', 'Wheelbase', 'Make'],
#  ['Origin', 'Type', 'Length', 'Weight', 'Wheelbase', 'Make', 'Horsepower'],
#  ['Origin', 'Type', 'Length', 'Weight', 'Wheelbase', 'Horsepower', 'Make'],
#  ['Origin', 'Type', 'Length', 'Wheelbase', 'Make', 'Horsepower', 'Weight'],
#  ['Origin', 'Type', 'Length', 'Wheelbase', 'Make', 'Weight', 'Horsepower'],
#  ['Origin', 'Type', 'Length', 'Wheelbase', 'Horsepower', 'Make', 'Weight'],
#  ['Origin', 'Type', 'Length', 'Wheelbase', 'Horsepower', 'Weight', 'Make'],
#  ['Origin', 'Type', 'Length', 'Wheelbase', 'Weight', 'Make', 'Horsepower'],
#  ['Origin', 'Type', 'Length', 'Wheelbase', 'Weight', 'Horsepower', 'Make'],
#  ['Origin', 'Type', 'Weight', 'Make', 'Horsepower', 'Length', 'Wheelbase'],
#  ['Origin', 'Type', 'Weight', 'Make', 'Horsepower', 'Wheelbase', 'Length'],
#  ['Origin', 'Type', 'Weight', 'Make', 'Length', 'Horsepower', 'Wheelbase'],
#  ['Origin', 'Type', 'Weight', 'Make', 'Length', 'Wheelbase', 'Horsepower'],
#  ['Origin', 'Type', 'Weight', 'Make', 'Wheelbase', 'Horsepower', 'Length'],
#  ['Origin', 'Type', 'Weight', 'Make', 'Wheelbase', 'Length', 'Horsepower'],
#  ['Origin', 'Type', 'Weight', 'Horsepower', 'Make', 'Length', 'Wheelbase'],
#  ['Origin', 'Type', 'Weight', 'Horsepower', 'Make', 'Wheelbase', 'Length'],
#  ['Origin', 'Type', 'Weight', 'Horsepower', 'Length', 'Make', 'Wheelbase'],
#  ['Origin', 'Type', 'Weight', 'Horsepower', 'Length', 'Wheelbase', 'Make'],
#  ['Origin', 'Type', 'Weight', 'Horsepower', 'Wheelbase', 'Make', 'Length'],
#  ['Origin', 'Type', 'Weight', 'Horsepower', 'Wheelbase', 'Length', 'Make'],
#  ['Origin', 'Type', 'Weight', 'Length', 'Make', 'Horsepower', 'Wheelbase'],
#  ['Origin', 'Type', 'Weight', 'Length', 'Make', 'Wheelbase', 'Horsepower'],
#  ['Origin', 'Type', 'Weight', 'Length', 'Horsepower', 'Make', 'Wheelbase'],
#  ['Origin', 'Type', 'Weight', 'Length', 'Horsepower', 'Wheelbase', 'Make'],
#  ['Origin', 'Type', 'Weight', 'Length', 'Wheelbase', 'Make', 'Horsepower'],
#  ['Origin', 'Type', 'Weight', 'Length', 'Wheelbase', 'Horsepower', 'Make'],
#  ['Origin', 'Type', 'Weight', 'Wheelbase', 'Make', 'Horsepower', 'Length'],
#  ['Origin', 'Type', 'Weight', 'Wheelbase', 'Make', 'Length', 'Horsepower'],
#  ['Origin', 'Type', 'Weight', 'Wheelbase', 'Horsepower', 'Make', 'Length'],
#  ['Origin', 'Type', 'Weight', 'Wheelbase', 'Horsepower', 'Length', 'Make'],
#  ['Origin', 'Type', 'Weight', 'Wheelbase', 'Length', 'Make', 'Horsepower'],
#  ['Origin', 'Type', 'Weight', 'Wheelbase', 'Length', 'Horsepower', 'Make'],
#  ['Origin', 'Type', 'Wheelbase', 'Make', 'Horsepower', 'Length', 'Weight'],
#  ['Origin', 'Type', 'Wheelbase', 'Make', 'Horsepower', 'Weight', 'Length'],
#  ['Origin', 'Type', 'Wheelbase', 'Make', 'Length', 'Horsepower', 'Weight'],
#  ['Origin', 'Type', 'Wheelbase', 'Make', 'Length', 'Weight', 'Horsepower'],
#  ['Origin', 'Type', 'Wheelbase', 'Make', 'Weight', 'Horsepower', 'Length'],
#  ['Origin', 'Type', 'Wheelbase', 'Make', 'Weight', 'Length', 'Horsepower'],
#  ['Origin', 'Type', 'Wheelbase', 'Horsepower', 'Make', 'Length', 'Weight'],
#  ['Origin', 'Type', 'Wheelbase', 'Horsepower', 'Make', 'Weight', 'Length'],
#  ['Origin', 'Type', 'Wheelbase', 'Horsepower', 'Length', 'Make', 'Weight'],
#  ['Origin', 'Type', 'Wheelbase', 'Horsepower', 'Length', 'Weight', 'Make'],
#  ['Origin', 'Type', 'Wheelbase', 'Horsepower', 'Weight', 'Make', 'Length'],
#  ['Origin', 'Type', 'Wheelbase', 'Horsepower', 'Weight', 'Length', 'Make'],
#  ['Origin', 'Type', 'Wheelbase', 'Length', 'Make', 'Horsepower', 'Weight'],
#  ['Origin', 'Type', 'Wheelbase', 'Length', 'Make', 'Weight', 'Horsepower'],
#  ['Origin', 'Type', 'Wheelbase', 'Length', 'Horsepower', 'Make', 'Weight'],
#  ['Origin', 'Type', 'Wheelbase', 'Length', 'Horsepower', 'Weight', 'Make'],
#  ['Origin', 'Type', 'Wheelbase', 'Length', 'Weight', 'Make', 'Horsepower'],
#  ['Origin', 'Type', 'Wheelbase', 'Length', 'Weight', 'Horsepower', 'Make'],
#  ['Origin', 'Type', 'Wheelbase', 'Weight', 'Make', 'Horsepower', 'Length'],
#  ['Origin', 'Type', 'Wheelbase', 'Weight', 'Make', 'Length', 'Horsepower'],
#  ['Origin', 'Type', 'Wheelbase', 'Weight', 'Horsepower', 'Make', 'Length'],
#  ['Origin', 'Type', 'Wheelbase', 'Weight', 'Horsepower', 'Length', 'Make'],
#  ['Origin', 'Type', 'Wheelbase', 'Weight', 'Length', 'Make', 'Horsepower'],
#  ['Origin', 'Type', 'Wheelbase', 'Weight', 'Length', 'Horsepower', 'Make'],
#  ['Origin', 'Horsepower', 'Make', 'Type', 'Length', 'Weight', 'Wheelbase'],
#  ['Origin', 'Horsepower', 'Make', 'Type', 'Length', 'Wheelbase', 'Weight'],
#  ['Origin', 'Horsepower', 'Make', 'Type', 'Weight', 'Length', 'Wheelbase'],
#  ['Origin', 'Horsepower', 'Make', 'Type', 'Weight', 'Wheelbase', 'Length'],
#  ['Origin', 'Horsepower', 'Make', 'Type', 'Wheelbase', 'Length', 'Weight'],
#  ['Origin', 'Horsepower', 'Make', 'Type', 'Wheelbase', 'Weight', 'Length'],
#  ['Origin', 'Horsepower', 'Make', 'Length', 'Type', 'Weight', 'Wheelbase'],
#  ['Origin', 'Horsepower', 'Make', 'Length', 'Type', 'Wheelbase', 'Weight'],
#  ['Origin', 'Horsepower', 'Make', 'Length', 'Weight', 'Type', 'Wheelbase'],
#  ['Origin', 'Horsepower', 'Make', 'Length', 'Weight', 'Wheelbase', 'Type'],
#  ['Origin', 'Horsepower', 'Make', 'Length', 'Wheelbase', 'Type', 'Weight'],
#  ['Origin', 'Horsepower', 'Make', 'Length', 'Wheelbase', 'Weight', 'Type'],
#  ['Origin', 'Horsepower', 'Make', 'Weight', 'Type', 'Length', 'Wheelbase'],
#  ['Origin', 'Horsepower', 'Make', 'Weight', 'Type', 'Wheelbase', 'Length'],
#  ['Origin', 'Horsepower', 'Make', 'Weight', 'Length', 'Type', 'Wheelbase'],
#  ['Origin', 'Horsepower', 'Make', 'Weight', 'Length', 'Wheelbase', 'Type'],
#  ['Origin', 'Horsepower', 'Make', 'Weight', 'Wheelbase', 'Type', 'Length'],
#  ['Origin', 'Horsepower', 'Make', 'Weight', 'Wheelbase', 'Length', 'Type'],
#  ['Origin', 'Horsepower', 'Make', 'Wheelbase', 'Type', 'Length', 'Weight'],
#  ['Origin', 'Horsepower', 'Make', 'Wheelbase', 'Type', 'Weight', 'Length'],
#  ['Origin', 'Horsepower', 'Make', 'Wheelbase', 'Length', 'Type', 'Weight'],
#  ['Origin', 'Horsepower', 'Make', 'Wheelbase', 'Length', 'Weight', 'Type'],
#  ['Origin', 'Horsepower', 'Make', 'Wheelbase', 'Weight', 'Type', 'Length'],
#  ['Origin', 'Horsepower', 'Make', 'Wheelbase', 'Weight', 'Length', 'Type'],
#  ['Origin', 'Horsepower', 'Type', 'Make', 'Length', 'Weight', 'Wheelbase'],
#  ['Origin', 'Horsepower', 'Type', 'Make', 'Length', 'Wheelbase', 'Weight'],
#  ['Origin', 'Horsepower', 'Type', 'Make', 'Weight', 'Length', 'Wheelbase'],
#  ['Origin', 'Horsepower', 'Type', 'Make', 'Weight', 'Wheelbase', 'Length'],
#  ['Origin', 'Horsepower', 'Type', 'Make', 'Wheelbase', 'Length', 'Weight'],
#  ['Origin', 'Horsepower', 'Type', 'Make', 'Wheelbase', 'Weight', 'Length'],
#  ['Origin', 'Horsepower', 'Type', 'Length', 'Make', 'Weight', 'Wheelbase'],
#  ['Origin', 'Horsepower', 'Type', 'Length', 'Make', 'Wheelbase', 'Weight'],
#  ['Origin', 'Horsepower', 'Type', 'Length', 'Weight', 'Make', 'Wheelbase'],
#  ['Origin', 'Horsepower', 'Type', 'Length', 'Weight', 'Wheelbase', 'Make'],
#  ['Origin', 'Horsepower', 'Type', 'Length', 'Wheelbase', 'Make', 'Weight'],
#  ['Origin', 'Horsepower', 'Type', 'Length', 'Wheelbase', 'Weight', 'Make'],
#  ['Origin', 'Horsepower', 'Type', 'Weight', 'Make', 'Length', 'Wheelbase'],
#  ['Origin', 'Horsepower', 'Type', 'Weight', 'Make', 'Wheelbase', 'Length'],
#  ['Origin', 'Horsepower', 'Type', 'Weight', 'Length', 'Make', 'Wheelbase'],
#  ['Origin', 'Horsepower', 'Type', 'Weight', 'Length', 'Wheelbase', 'Make'],
#  ...]

# %%
dfff = pandas.DataFrame(perm_index)
dfff
# Out:
#               0       1       2           3          4          5          6
# 0          Make  Origin    Type  Horsepower     Length     Weight  Wheelbase
# 1          Make  Origin    Type  Horsepower     Length  Wheelbase     Weight
# 2          Make  Origin    Type  Horsepower     Weight     Length  Wheelbase
# 3          Make  Origin    Type  Horsepower     Weight  Wheelbase     Length
# 4          Make  Origin    Type  Horsepower  Wheelbase     Length     Weight
# ...         ...     ...     ...         ...        ...        ...        ...
# 5035  Wheelbase  Weight  Length  Horsepower       Make       Type     Origin
# 5036  Wheelbase  Weight  Length  Horsepower     Origin       Make       Type
# 5037  Wheelbase  Weight  Length  Horsepower     Origin       Type       Make
# 5038  Wheelbase  Weight  Length  Horsepower       Type       Make     Origin
# 5039  Wheelbase  Weight  Length  Horsepower       Type     Origin       Make
#
# [5040 rows x 7 columns]

# %%
def SWEEPOperator (pDim, inputM, origDiag, sweepCol = None, tol = 1e-7):
    ''' Implement the SWEEP operator
    Parameter
    ---------
    pDim: dimension of matrix inputM, integer greater than one
    inputM: a square and symmetric matrix, numpy array
    origDiag: the original diagonal elements before any SWEEPing
    sweepCol: a list of columns numbers to SWEEP
    tol: singularity tolerance, positive real
    Return
    ------
    A: negative of a generalized inverse of input matrix
    aliasParam: a list of aliased rows/columns in input matrix
    nonAliasParam: a list of non-aliased rows/columns in input matrix
    '''
    if (sweepCol is None):
        sweepCol = range(pDim)
    aliasParam = []
    nonAliasParam = []
    A = numpy.copy(inputM)
    ANext = numpy.zeros((pDim,pDim))
    for k in sweepCol:
        Akk = A[k,k]
        pivot = tol * abs(origDiag[k])
        if (not numpy.isinf(Akk) and abs(Akk) >= pivot and pivot > 0.0):
            nonAliasParam.append(k)
            ANext = A - numpy.outer(A[:, k], A[k, :]) / Akk
            ANext[:, k] = A[:, k] / abs(Akk)
            ANext[k, :] = ANext[:, k]
            ANext[k, k] = -1.0 / Akk
        else:
            aliasParam.append(k)
            ANext[:,k] = numpy.zeros(pDim)
            ANext[k, :] = numpy.zeros(pDim)
        A = ANext
    return (A, aliasParam, nonAliasParam)
def LinearRegression (X, y):
    ''' Train a linear regression model
    Parameter
    ---------
    X: A Pandas DataFrame, rows are observations, columns are regressors
    y: A Pandas Series, rows are observations of the response variable
    Return
    ------
    A list of the following entities:
    1. b: an array of regression coefficient
    2. residual_SS: residual sum of squares
    3. XtX_Ginv: a generalized inverse of the XtX matrix
    4. aliasParam: a list of aliased rows/columns in input matrix
    5. nonAliasParam: a list of non-aliased rows/columns in input matrix
    '''
    # X: A Pandas DataFrame, rows are observations, columns are regressors
    # y: A Pandas Series, rows are observations of the response variable
    Z = X.join(y)
    n_sample = Z.shape[0]
    n_param = Z.shape[1] - 1
    ZtZ = Z.transpose().dot(Z)
    diag_ZtZ = numpy.diagonal(ZtZ)
    eps_double = numpy.finfo(numpy.float64).eps
    tol = numpy.sqrt(eps_double)
    ZtZ_transf, aliasParam, nonAliasParam = SWEEPOperator ((n_param+1), ZtZ, 
diag_ZtZ, sweepCol = range(n_param), tol = tol)
    b = ZtZ_transf[0:n_param, n_param]
    b[aliasParam] = 0.0
    XtX_Ginv = - ZtZ_transf[0:n_param, 0:n_param]
    XtX_Ginv[:, aliasParam] = 0.0
    XtX_Ginv[aliasParam, :] = 0.0
    residual_SS = ZtZ_transf[n_param, n_param]
    return ([b, residual_SS, XtX_Ginv, aliasParam, nonAliasParam])

# %%
for i in range(len(dfff.index)):
    #set the varr as the list of each row, and the first 7 elements of each row must be the features
    varr = dfff.loc[i,:].to_list()
    for j in range(7):
        #select the related features
        list_para = varr[0:j+1]
        X12 = df[list_para]
        X12.insert(0, 'Intercept', 1.0)
        y = data['MPG_City']
        result_list12 = LinearRegression(X12, y)
        residual_SS12 = result_list12[1]
        #calculate the r-squared
        r_sq12 = 1 - (residual_SS12/tss(y))
        #name the predictor columns
        pred_name = "Predictor" + str(j)
        #if the column exists, add the value to the corresponding cell
        if pred_name in dfff.columns:
        #change the designated cell
            dfff.at[i, pred_name] = r_sq12
        #otherwise, add the new column and name it.
        else:
            dfff[pred_name] = r_sq12

# %%
dfff
# Out:
#               0       1       2           3          4          5          6  \
# 0          Make  Origin    Type  Horsepower     Length     Weight  Wheelbase
# 1          Make  Origin    Type  Horsepower     Length  Wheelbase     Weight
# 2          Make  Origin    Type  Horsepower     Weight     Length  Wheelbase
# 3          Make  Origin    Type  Horsepower     Weight  Wheelbase     Length
# 4          Make  Origin    Type  Horsepower  Wheelbase     Length     Weight
# ...         ...     ...     ...         ...        ...        ...        ...
# 5035  Wheelbase  Weight  Length  Horsepower       Make       Type     Origin
# 5036  Wheelbase  Weight  Length  Horsepower     Origin       Make       Type
# 5037  Wheelbase  Weight  Length  Horsepower     Origin       Type       Make
# 5038  Wheelbase  Weight  Length  Horsepower       Type       Make     Origin
# 5039  Wheelbase  Weight  Length  Horsepower       Type     Origin       Make
#
#       Predictor0  Predictor1  Predictor2  Predictor3  Predictor4  Predictor5  \
# 0       0.026752    0.063714    0.067052    0.481109    0.533970    0.633492
# 1       0.026752    0.063714    0.067052    0.481109    0.533970    0.538952
# 2       0.026752    0.063714    0.067052    0.481109    0.633368    0.633492
# 3       0.026752    0.063714    0.067052    0.481109    0.633368    0.637543
# 4       0.026752    0.063714    0.067052    0.481109    0.535801    0.538952
# ...          ...         ...         ...         ...         ...         ...
# 5035    0.257337    0.551538    0.558849    0.624186    0.626177    0.638894
# 5036    0.257337    0.551538    0.558849    0.624186    0.628332    0.628878
# 5037    0.257337    0.551538    0.558849    0.624186    0.628332    0.640126
# 5038    0.257337    0.551538    0.558849    0.624186    0.636252    0.638894
# 5039    0.257337    0.551538    0.558849    0.624186    0.636252    0.640126
#
#       Predictor6
# 0       0.641107
# 1       0.641107
# 2       0.641107
# 3       0.641107
# 4       0.641107
# ...          ...
# 5035    0.641107
# 5036    0.641107
# 5037    0.641107
# 5038    0.641107
# 5039    0.641107
#
# [5040 rows x 14 columns]

# %%
dfff1 = dfff.iloc[:,0:7]
dfff2 = dfff.iloc[:,7:14]

# %%
dfff3 = pandas.DataFrame()

# %%
dfff3['Predictor0'] = dfff2['Predictor0']
dfff3['Predictor1'] = dfff2['Predictor1'] - dfff2['Predictor0']
dfff3['Predictor2'] = dfff2['Predictor2'] - dfff2['Predictor1']
dfff3['Predictor3'] = dfff2['Predictor3'] - dfff2['Predictor2']
dfff3['Predictor4'] = dfff2['Predictor4'] - dfff2['Predictor3']
dfff3['Predictor5'] = dfff2['Predictor5'] - dfff2['Predictor4']
dfff3['Predictor6'] = dfff2['Predictor6'] - dfff2['Predictor5']
dfff3
# Out:
#       Predictor0  Predictor1  Predictor2  Predictor3  Predictor4  Predictor5  \
# 0       0.026752    0.036962    0.003338    0.414056    0.052861    0.099522
# 1       0.026752    0.036962    0.003338    0.414056    0.052861    0.004982
# 2       0.026752    0.036962    0.003338    0.414056    0.152259    0.000124
# 3       0.026752    0.036962    0.003338    0.414056    0.152259    0.004175
# 4       0.026752    0.036962    0.003338    0.414056    0.054693    0.003151
# ...          ...         ...         ...         ...         ...         ...
# 5035    0.257337    0.294201    0.007312    0.065337    0.001991    0.012718
# 5036    0.257337    0.294201    0.007312    0.065337    0.004146    0.000546
# 5037    0.257337    0.294201    0.007312    0.065337    0.004146    0.011793
# 5038    0.257337    0.294201    0.007312    0.065337    0.012066    0.002642
# 5039    0.257337    0.294201    0.007312    0.065337    0.012066    0.003874
#
#       Predictor6
# 0       0.007615
# 1       0.102155
# 2       0.007615
# 3       0.003564
# 4       0.102155
# ...          ...
# 5035    0.002213
# 5036    0.012229
# 5037    0.000981
# 5038    0.002213
# 5039    0.000981
#
# [5040 rows x 7 columns]

# %%
col12 = ['Make', 'Origin', 'Type', 'Horsepower', 'Length', 'Weight', 'Wheelbase']
dict_pred = {'Make': 0, 'Origin': 0, 'Type': 0, 'Horsepower': 0, 'Length': 0, 'Weight': 0, 'Wheelbase': 0}  
dict_pred1 = dict_pred

# %%
for i in range(len(dfff1.index)):
    variables = dfff1.loc[i,:].to_list()
    pred_diff = dfff3.loc[i,:].to_list()
    for j in range(7):
        dict_pred[variables[j]] += pred_diff[j]
dict_pred
# Out:
# {'Make': 31.84065274050079,
#  'Origin': 73.40952453693774,
#  'Type': 45.5482272707267,
#  'Horsepower': 1050.9494893478136,
#  'Length': 341.0860556706681,
#  'Weight': 1323.6873757129083,
#  'Wheelbase': 364.65838245209807}

# %% [markdown]
# **Calculate the Shap Value for each feature**

# %%
dic_keys = dict_pred.keys()
sum_rsq = 0
for i in dic_keys:
    #Calculate the average sum
    dict_pred[i] = dict_pred[i] / 5040
    sum_rsq += dict_pred[i]

dict_pred
# Out:
# {'Make': 0.006317589829464443,
#  'Origin': 0.014565381852567012,
#  'Type': 0.009037346680699741,
#  'Horsepower': 0.20852172407694713,
#  'Length': 0.06767580469656113,
#  'Weight': 0.2626363840700215,
#  'Wheelbase': 0.07235285366113058}

# %%
sum_rsq
# Out:
# 0.6411070848673915

# %%
df_shapval = pandas.DataFrame.from_dict(dict_pred, orient='index', columns=['Shap Value'])
df_shapval['Percent Shape'] = df_shapval['Shap Value'] / sum_rsq
df_shapval
# Out:
#             Shap Value  Percent Shape
# Make          0.006318       0.009854
# Origin        0.014565       0.022719
# Type          0.009037       0.014096
# Horsepower    0.208522       0.325253
# Length        0.067676       0.105561
# Weight        0.262636       0.409661
# Wheelbase     0.072353       0.112856
